# %%
from googleapiclient.discovery import build 
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
# API KEY CONNECTION
def Api_connect():
    Api_ID="AIzaSyDP94O9vMrVdU0lChq_UEV19_uGD1S_9tU"
    api_service_name="youtube"
    api_version="v3"

    youtube=build(api_service_name,api_version,developerKey=Api_ID)

    return youtube
youtube=Api_connect()

# %%
# Get channel information
def get_channel_info(channel_id):
    request=youtube.channels().list(
                    part="snippet,ContentDetails,statistics",
                    id=channel_id
    )
    response=request.execute()

    for i in response['items']:
        data=dict(Channel_Name=i["snippet"]["title"],
                Channel_ID=i["id"],
                Subscribers=i["statistics"]["subscriberCount"],
                Views=i["statistics"]["viewCount"],
                Total_vedios=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]["description"],
                Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data

# %%
channel_details=get_channel_info("UChGd9JY4yMegY6PxqpBjpRA")

# %%
channel_details
# Out:
# {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#  'Channel_ID': 'UChGd9JY4yMegY6PxqpBjpRA',
#  'Subscribers': '70600',
#  'Views': '4669261',
#  'Total_vedios': '276',
#  'Channel_Description': 'நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பானில் 1.5 வருட ஆராய்ச்சி, அமெரிக்காவில் 2 வருட ஆராய்ச்சி, ஐரோப்பாவில் சுமார் 6 வருட ஆராய்ச்சி ! தற்போது நம்ம ஊரில்  !\n\nஎளிய தமிழில் அனைவரும் ஆர்வமுடன் அறிவியலை தெரிந்துகொள்ளவேண்டும் என்ற நோக்கத்தில் இந்த முயற்சி! என்னுடன் தொடர்பு கொள்ள விரும்பினால் sciencewithsam2020@gmail.com\n\nConnect with me by email sciencewithsam2020@gmail.com\n\nநான் யாரிடமும் பணமோ உதவியோ இந்த சேனல் மூலம் கேட்பதில்லை. ஒரு வேலை என்னுடைய சேனலுக்கு உதவ விரும்பும் நண்பர்கள், எனது GPay ID samuelpaul83@oksbi.\n\nI never ask for money through my channel. If you really want to support my work by any means, you can do so through my GPay account samuelpaul83@oksbi.\n\n',
#  'Playlist_Id': 'UUhGd9JY4yMegY6PxqpBjpRA'}

# %%
#get video ids
def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None

    while True:
        response1=youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')
        
        if next_page_token is None:
            break
    return video_ids

# %%
Video_Ids=get_videos_ids("UChGd9JY4yMegY6PxqpBjpRA")

# %%
Video_Ids
# Out:
# ['jTvSZOHhDzA',
#  'YAfkc0ksRdw',
#  '_a1-QpK3aqQ',
#  'TbISw1Yt_1U',
#  'irLLYHYLrQs',
#  'tui7G5ZCeLo',
#  'RIrgGRA8PNk',
#  'SZSOjeT2-Yo',
#  'CSsRypCejjQ',
#  'B8FzwsamIjY',
#  'mFKi_DvBagE',
#  'eRod4CE2gRo',
#  'dz6xI5mTisk',
#  'z1cjXPTCWQA',
#  'h40Y05iZm_s',
#  'yksgUtc4F5M',
#  'GW7tQGoQSMA',
#  'K5OoR-Uo7xM',
#  'QkPhSjo7nsI',
#  'pSLahAy8nC4',
#  'JgzEOrPmaDI',
#  'FTLBylwmrlk',
#  'fjcoW3dtuGM',
#  'IezbYe4KnAg',
#  'Sso4-56DB_g',
#  'D3jiAxVmYr4',
#  'qK3WhbtnYiE',
#  'u8Taq7BftzI',
#  'axyB8eJfA_g',
#  'jUuXuT8OCCc',
#  'G2Hpsf6VjII',
#  'q7CCuy-z16w',
#  '4OzQep0O188',
#  'NLt8jvfRzdE',
#  'YlBN1q_C36g',
#  'I8-ePNI1dOA',
#  'lRsV8HPNmOs',
#  'BKeyxTrBbnY',
#  'fK-9tNPZwl0',
#  '3YLM4syCmm8',
#  'j58-HbDWRww',
#  'hFwavrH8BLU',
#  'UfutXnYu7R8',
#  'uQuwBs7RJHw',
#  'KpuRyc00_t0',
#  'E5O7Nx6lpu0',
#  'qIyIA68T1FY',
#  'PoS7ifimbpk',
#  'NlvuPsZtQJw',
#  'UaBKxzBhdqk',
#  'mRBCCWoK2Qw',
#  'd4Cz8Vcg3tY',
#  'hoJw8D4DrLc',
#  'uob4vPknXkI',
#  'fnnqJ_COroo',
#  'uj2t-A2zACM',
#  'UmCb-7mNREE',
#  'mMpvW8cZDwo',
#  'N6ZV9jPQok0',
#  'RPfhLGAKK3Q',
#  'ruxVRaCchtI',
#  '85aiJYOdK_w',
#  'qqb3HazZLMs',
#  '6yIDo13llWQ',
#  'G6Zvjkz_hSM',
#  '1Vtr7-kWB4I',
#  'tjRZK_1XAro',
#  'mieGqJ0BXiE',
#  'rggw1Izwbf0',
#  'wk30gfF_C_w',
#  'w8D181wzNAE',
#  'Rsv1Gee1X3k',
#  'Uug8GbypVeE',
#  'w-skmswzslw',
#  '-WCqyL_maXw',
#  'IkUnfZ3DZ5E',
#  'UMJNo2AsBIw',
#  'GzsO5iDWFzE',
#  '0F9yBSVORiw',
#  '0m_GL1s48PM',
#  'SahrxeFDOTU',
#  'cklmbSyiDWw',
#  'W-cOYQenl-8',
#  '40nAkEJzQfU',
#  'Z-EXgiNUBA4',
#  '2-RF5URMwiA',
#  'vzh3TNGvRoI',
#  'YDAHEdLFKlw',
#  'jeQMuKJLL6c',
#  'JIfhCzk0Qe0',
#  'OsxGwNSqsoQ',
#  'Ih3K9C6Am4o',
#  'lEMEFIill2w',
#  'xiND3txiVUU',
#  'PAT1VMOf-g4',
#  '9e17CXMgCew',
#  'wtD7UflK1qw',
#  'OrpxceNF4CM',
#  'FxhUEKmr6Z4',
#  's4WDqiSO5xA',
#  'QtHKeTvJZVg',
#  'ydROlWxg-F0',
#  'TAZsy6eW5lg',
#  '-Bm8pkfEyV4',
#  'NgevvQ07AE0',
#  'TY7fWhxW5kc',
#  'pqHbuJG3slw',
#  'nYsz_d6GwfE',
#  'TitA0sTkEG0',
#  'ZWVQkdzu73A',
#  '6bI3ANM6XVk',
#  '1-LYbjM2Dqk',
#  'SZ1okoINcMQ',
#  'm6oQJtgEBc4',
#  'txOSCaXeIWk',
#  'zZYgvfIG9Tg',
#  '0lotQT0RVHw',
#  'qIkrm8IOqMw',
#  'fypZd-LX9MM',
#  'HzGvRiMIOYw',
#  'ggZ42AbcO6E',
#  '__Oy83p64SU',
#  'IQAHqC6GXdY',
#  '4WB05Uuaitc',
#  'NLggvZqb4-A',
#  'TM7P3ZfUnl0',
#  'R5lq1cQdCBo',
#  'ecmXIbNuwVA',
#  'gttiv7cJXpQ',
#  'Yybi0qnfWgU',
#  'frvYbjWXOKw',
#  'akO3XwAvBGY',
#  'k3Iav37Df9E',
#  'L4jk1isSuOI',
#  '2kgB7i2hH-c',
#  'af4EHM2pbmQ',
#  'mZZMzF11zaE',
#  'bgFrMm2XgFg',
#  'BZ7VcMdeD3g',
#  'PSsClm5m1Bo',
#  '_O6rhPY4QR0',
#  'oZ94AdtLm4o',
#  '-5Y92EMuc5E',
#  '6f1munXQUoo',
#  'gwkGzXAcSL8',
#  'rtGuRxg6i84',
#  'ParjXaRce58',
#  'hVMwDfDcWJ4',
#  'mRrmkHxd3QY',
#  'FlbmzyDQMu4',
#  'lL9xjotTiog',
#  'uZ8-8dOMEjc',
#  'bXqPDI75_d4',
#  'YuR3x9rr9OI',
#  '9pfjECrgtvQ',
#  'x4PPCViqQ1I',
#  'gToa-y6QoUk',
#  '0Uc5O7ICfXk',
#  'J5ojfRvs6ho',
#  'EKqPOy0GYds',
#  'fXORmRmN9Dg',
#  'le9Gma-pwzc',
#  'cjkTNVYP1KA',
#  'YOAh6pioIEc',
#  'N-slORdrSPs',
#  '-hs3mIAcyV8',
#  'Mb-5T6TArYs',
#  'frNtVnFnLBc',
#  'AUztMVwjo5g',
#  'rWaSAg0QjgQ',
#  'Up5Xu7fmOgg',
#  'KKT7353JKhw',
#  '6QLhrenhvM4',
#  'hWQQJcjjNHc',
#  'LthMtYl2Snw',
#  'HmQVFXLbYOM',
#  'Bi7g_umT1dY',
#  'uw036FhAsZc',
#  'GlFl1XLv0FY',
#  '0BmrMyI5E1w',
#  '0vGybNs0DJo',
#  '3-TiYWpL9mY',
#  '2kl5TNjskAk',
#  '4PC4PDFawV4',
#  'Gm22nTZqJUk',
#  'JshtVqvJwMQ',
#  'x8kkBTsIFf8',
#  'gU_qHITVDeE',
#  'gLYmttnvpCQ',
#  '5ddKRkJd5ts',
#  '7mNTQzaXp20',
#  'KiVH9gSMVIk',
#  'KxeD1bYJlt0',
#  '24W2GZagFnw',
#  'G37JWyJRwe0',
#  '3TUzC2yyr4s',
#  'BRrNRwvlHVk',
#  'B4A1h2bTdDY',
#  'o61cfHWRuD4',
#  'h4vxjVxdWME',
#  'uRcF7_pClSM',
#  '_xY8Qz6vb8I',
#  'gM70BEUS9aw',
#  'UkmpZ4vzqh0',
#  'azy3h1YQVik',
#  'ce-E-pmoZ4c',
#  'bLOi1bSUBvs',
#  'BKDv0TApWvY',
#  'lfhFgzT-5Kc',
#  'zB0p8WSMW8U',
#  'RU26gxKpf1k',
#  'GHPpYngk9rs',
#  '5_ozhqxuM0c',
#  'dGuW19nOWHw',
#  'tdpj78n3y3E',
#  'Fmn57AJGbsA',
#  'L82uJC1EgRk',
#  '3yiHw36iUgk',
#  '9lBobn-UGPg',
#  'xu15uzuEiuk',
#  'HsfKtMROCWg',
#  'KgEYn2WLFHk',
#  'LK8qdNg3cBI',
#  'yQqsfC4Pw8s',
#  'wjYs45ScBA8',
#  '-q0SL8Cm_F0',
#  'J1OdDFeXQn0',
#  'o3M0qbUUHW0',
#  'weUZl1gSsvg',
#  'eSPGDQja8Qg',
#  '-B9y18v96Os',
#  '6RyDc-D2f7g',
#  'CUPz-E-C3ug',
#  'CbRrXRuJg0c',
#  'MByMwmqrNiI',
#  'CsJGd5zqJQI',
#  'bEJXVQYdhMU',
#  'CLgfReYJ2rk',
#  'GbzUpKysCqg',
#  'icPAhpbYAYQ',
#  '5Kjk2LepbsE',
#  '2l8xcWvMfPM',
#  'tV_rpUWvZEM',
#  'a1p-YN2m--4',
#  '3B_nkzvU_XQ',
#  'YBV9X3cy-YI',
#  'NufjXnBa3fU',
#  'lJG2Is_uOPo',
#  'ogncVQNVBs0',
#  'g4Cv0qmNpkM',
#  'dW1Du_zgYwQ',
#  'QusGXbGm7gI',
#  'iz8Rh9HCutc',
#  'pajRi7pt0C0',
#  'Nykz9_Vh2Bo',
#  'zcvArp8CSrk',
#  'DUxNSZg95m8',
#  'VPdRgL9Wlho',
#  'MYEpZs9zqFQ',
#  'QYUdzoW8Ecw',
#  'rkt_wMoIz3U',
#  '7pp90cY3cws',
#  'jLxX9QCf3zs',
#  'lGUocqYnDtQ',
#  'wQtxHEpWtLc',
#  'J0j9KPDjPXI',
#  'vhKlZIV_9Lg',
#  'X6Zgh_Ww9qk',
#  'pHVUjoiC8ts',
#  'mFbIdGkmGQ0',
#  'CK-Z2H23aNY',
#  'r4atlpx48Ow',
#  'o2YAzhcnN30',
#  'cFd0i4UyPpU',
#  'sAuoNwN2qMU',
#  'rFnCy_tn5Lo']

# %%
len(Video_Ids)
# Out:
# 276

# %%
#get video information
def get_video_info(video_ids):
    video_data=[]

    for video_id in video_ids:
        request=youtube.videos().list(
            part='snippet,contentDetails,statistics',
            id=video_id
        )
        response=request.execute()
        for item in response["items"]:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item['snippet'].get('tags'),
                    Thumbnail=item['snippet']['thumbnails']['default']['url'],
                    Descriptions=item['snippet'].get('description'),
                    Published_Date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=item['statistics'].get('viewCount'),
                    Likes=item['statistics'].get('likeCount'),
                    Comments=item['statistics'].get('commentCount'),
                    Favorite_Count=item['statistics']['favoriteCount'],
                    Definition=item['contentDetails']['definition'],
                    Caption_Status=item['contentDetails']['caption'],
                    )
            video_data.append(data)
    return video_data

# %%
video_details=get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Title': '2024 Chemistry Nobel Prize in Tamil | Protein Structure | Google DeepMind |',
#   'Tags': ['#sciencewithsam', '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/jTvSZOHhDzA/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-10-09T13:35:38Z',
#   'Duration': 'PT6M45S',
#   'Views': '3804',
#   'Likes': '240',
#   'Comments': '23',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Title': 'Physics Nobel Prize 2024 in Simple Tamil | Why Physics prize for AI and ML? |',
#   'Tags': ['#sciencewithsam', '#nobelprize2024', 'tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YAfkc0ksRdw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-10-09T09:56:08Z',
#   'Duration': 'PT13M36S',
#   'Views': '9951',
#   'Likes': '502',
#   'Comments': '63',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Title': '2024 Physics Nobel Prize | Tamil | Artificial Neural Networks |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/_a1-QpK3aqQ/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-10-08T10:21:08Z',
#   'Duration': 'PT2M42S',
#   'Views': '2494',
#   'Likes': '168',
#   'Comments': '15',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Title': 'Schrodinger Equation Story | Story behind this famous equation | Tamil |',
#   'Tags': ['#tamilscience', '#schrodinger', '#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/TbISw1Yt_1U/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-10-03T16:37:56Z',
#   'Duration': 'PT17M33S',
#   'Views': '3487',
#   'Likes': '241',
#   'Comments': '66',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'irLLYHYLrQs',
#   'Title': 'de Broglie Wavelength | Second Quantum Revolution | Tamil | எலக்ட்ரான் அலையா துகளா?',
#   'Tags': ['#sciencewithsam',
#    '#tamilquantum',
#    '#sciencestory',
#    '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/irLLYHYLrQs/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-07-01T12:30:34Z',
#   'Duration': 'PT11M13S',
#   'Views': '7088',
#   'Likes': '367',
#   'Comments': '103',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'tui7G5ZCeLo',
#   'Title': 'Mass of A Photon | ஒளி துகளின் (PHOTON) நிறை | New Research Results |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/tui7G5ZCeLo/default.jpg',
#   'Descriptions': 'அன்பர்களுக்கு வணக்கம் ! இந்த காணொளி ஒளி துகளின் (PHOTON) நிறை பற்றிய சமீபத்திய ஆய்வு கட்டுரையின் முக்கிய கண்டுபிடிப்பை பற்றியது. ஆய்வு கட்டுரை என்பதால், சற்று அடிப்படை அறிவியலை விளக்கிவிட்டு, பின்னர் ஆய்வின் முக்கியத்தை  சொல்ல முயற்சித்திருக்கிறேன் ! அடிப்படை அறிவியல் தெரிந்தவர்களுக்கு இந்த காணொளியில் ஆரம்பம் சற்று சலிப்பை தரலாம். மற்றவர்களுக்கு புதிய அறிவியலாக  இருக்கும். பொறுமையாக கடைசி வரை கண்டால், இந்த ஆய்வின் முக்கியம் புரிந்துகொள்ளலாம். ஆங்காங்கே ஆய்வு கட்டுரையின் வரிகளையே காணொளியில் காட்டி இருக்கிறேன். ஒரு ஆய்வு கட்டுரையை வாசிக்கும் வாய்ப்பாக எடுத்து கொள்ளுங்கள். உங்களின் அன்பிற்கு நன்றிகள் - அன்புடன் உங்கள் சாம்   \n\nLink for the research article is \n\nhttps://iopscience.iop.org/article/10.3847/1538-4357/ad2f99',
#   'Published_Date': '2024-06-25T18:19:15Z',
#   'Duration': 'PT12M45S',
#   'Views': '19441',
#   'Likes': '828',
#   'Comments': '155',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'RIrgGRA8PNk',
#   'Title': 'Einstein & Schrodinger In Switzerland | Tamil | Schrodinger Life Story | Second Quantum Revolution|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/RIrgGRA8PNk/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-06-19T12:00:26Z',
#   'Duration': 'PT11M40S',
#   'Views': '6985',
#   'Likes': '404',
#   'Comments': '57',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'SZSOjeT2-Yo',
#   'Title': 'Light Mass and Momentum | Light Has No Mass But Momentum - How? |',
#   'Tags': ['#sciencewithsam', '#tamilscience', '#photon'],
#   'Thumbnail': 'https://i.ytimg.com/vi/SZSOjeT2-Yo/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-06-13T17:11:17Z',
#   'Duration': 'PT7M42S',
#   'Views': '21421',
#   'Likes': '1234',
#   'Comments': '147',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'CSsRypCejjQ',
#   'Title': 'Bohr Atomic Model | அணு எப்படி இருக்கும்? அணுவில் இருந்து ஒளி எப்படி வரும்?| விடை தந்த குவாண்டம்|',
#   'Tags': ['#sciencewithsam', '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/CSsRypCejjQ/default.jpg',
#   'Descriptions': 'The book I referred for all the quantum story videos is "Erwin Schrödinger and the quantum revolution" by John Gribbin. Of course, other materials also I referred.',
#   'Published_Date': '2024-06-12T06:42:58Z',
#   'Duration': 'PT17M51S',
#   'Views': '132752',
#   'Likes': '2432',
#   'Comments': '157',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'B8FzwsamIjY',
#   'Title': 'Einstein Quantum Concept | Light Is A Particle | Tamil | Quantum Revolution Contd. |',
#   'Tags': ['#sciencewithsam', '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/B8FzwsamIjY/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-06-08T15:21:48Z',
#   'Duration': 'PT20M24S',
#   'Views': '12418',
#   'Likes': '602',
#   'Comments': '94',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'mFKi_DvBagE',
#   'Title': '#sciencefacts #tamilscience #sciencewithsam #sciencestory #tamilstory #tamilscientist',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/mFKi_DvBagE/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-06-08T07:28:02Z',
#   'Duration': 'PT57S',
#   'Views': '2500',
#   'Likes': '250',
#   'Comments': '15',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'eRod4CE2gRo',
#   'Title': "First Quantum Revolution | Black Body Radiation | Planck's Quantum Concept |",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/eRod4CE2gRo/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-06-01T17:28:18Z',
#   'Duration': 'PT19M46S',
#   'Views': '11442',
#   'Likes': '572',
#   'Comments': '65',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'dz6xI5mTisk',
#   'Title': 'Science Before Schrodinger| Boltzmann Science and His Suicide | Influence on Schrodinger |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/dz6xI5mTisk/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-05-30T09:36:17Z',
#   'Duration': 'PT19M5S',
#   'Views': '12352',
#   'Likes': '526',
#   'Comments': '78',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'z1cjXPTCWQA',
#   'Title': "Science Before Schrodinger| What is inside Light? | Maxwell's Physics That Influenced Schrodinger|",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/z1cjXPTCWQA/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-05-28T05:41:00Z',
#   'Duration': 'PT18M',
#   'Views': '63384',
#   'Likes': '2345',
#   'Comments': '215',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'h40Y05iZm_s',
#   'Title': "Science Before Schrodinger | Newton's Classical Physics Importance |",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/h40Y05iZm_s/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-05-24T13:49:42Z',
#   'Duration': 'PT19M51S',
#   'Views': '6435',
#   'Likes': None,
#   'Comments': '145',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'yksgUtc4F5M',
#   'Title': 'Who is C V Raman? What is Raman Effect? Why is this special? | Tamil | National Science Day Special|',
#   'Tags': ['#nationalscienceday', '#cvraman', '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yksgUtc4F5M/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-02-28T03:30:17Z',
#   'Duration': 'PT16M54S',
#   'Views': '9396',
#   'Likes': '460',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Title': 'Erwin Schrodinger - Life Story - 3| Tamil | College Life, First Meeting with Einstein, World War I|',
#   'Tags': ['#sciencewithsam',
#    '#tamilscientist',
#    '#scientiststoryintamil',
#    '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/GW7tQGoQSMA/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-02-14T14:39:52Z',
#   'Duration': 'PT17M34S',
#   'Views': '3235',
#   'Likes': '162',
#   'Comments': '23',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Title': 'Erwin Schrodinger - Life Story | Tamil | Part - 2| Childhood and School Life |',
#   'Tags': ['#scientiststory', '#schrodinger', '#quantum'],
#   'Thumbnail': 'https://i.ytimg.com/vi/K5OoR-Uo7xM/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-02-08T12:30:21Z',
#   'Duration': 'PT14M41S',
#   'Views': '2659',
#   'Likes': '149',
#   'Comments': '26',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Title': 'Erwin Schrodinger  - Life Story | Tamil | Part - 1| Quantum Revolutionary',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/QkPhSjo7nsI/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-02-05T14:05:17Z',
#   'Duration': 'PT10M15S',
#   'Views': '4708',
#   'Likes': '345',
#   'Comments': '54',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'pSLahAy8nC4',
#   'Title': 'உங்களால் எனக்கு கிடைத்த முதல் விருது | அனைவருக்கும் நன்றிகள்',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/pSLahAy8nC4/default.jpg',
#   'Descriptions': 'Thank you all from the bottom of my heart',
#   'Published_Date': '2024-01-09T13:28:34Z',
#   'Duration': 'PT2M20S',
#   'Views': '2613',
#   'Likes': '395',
#   'Comments': '148',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'JgzEOrPmaDI',
#   'Title': 'Happy New Year 2024 | Thank You All | ♥️♥️',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/JgzEOrPmaDI/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2024-01-01T15:20:49Z',
#   'Duration': 'PT3M',
#   'Views': '1106',
#   'Likes': '135',
#   'Comments': '54',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'FTLBylwmrlk',
#   'Title': 'Nobel Prize Chemistry 2023 Tamil | வேதியில் தேர்வில் FAIL - வேதியியலில் 2023 நோபல் பரிசு |',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FTLBylwmrlk/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-10-05T12:00:10Z',
#   'Duration': 'PT10M5S',
#   'Views': '10499',
#   'Likes': '501',
#   'Comments': '55',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'fjcoW3dtuGM',
#   'Title': 'Physics Nobel Prize 2023 in Tamil | அரிதான லேசரை உருவாக்கிய விஞ்ஞானிகள் | சாதித்த பெண் |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/fjcoW3dtuGM/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-10-03T11:30:58Z',
#   'Duration': 'PT8M53S',
#   'Views': '8930',
#   'Likes': '479',
#   'Comments': '70',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'IezbYe4KnAg',
#   'Title': 'Noble Prize 2023 for COVID Vaccine | Nobel Prize for Medicine | Hot News',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/IezbYe4KnAg/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-10-02T10:03:34Z',
#   'Duration': 'PT3M53S',
#   'Views': '2297',
#   'Likes': '163',
#   'Comments': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'Sso4-56DB_g',
#   'Title': 'Chandrayaan Important Discovery | சந்திரயானின் முக்கிய கண்டுபிடிப்பு | விளக்கிய வெளிநாட்டு விஞ்ஞானி|',
#   'Tags': ['#sciencewithsam', '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Sso4-56DB_g/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-09-28T13:00:20Z',
#   'Duration': 'PT11M9S',
#   'Views': '8263',
#   'Likes': '183',
#   'Comments': '21',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Title': 'Origin of Life | உயிர் உருவானது எப்படி | NASAவிற்கு கிடைத்த அறிய பொக்கிஷம் | Bennu Asteroid |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/D3jiAxVmYr4/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-09-25T12:30:07Z',
#   'Duration': 'PT12M21S',
#   'Views': '7098',
#   'Likes': '350',
#   'Comments': '45',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'qK3WhbtnYiE',
#   'Title': 'Quantum Mechanics Lecture - 8 | Entanglement | Mathematical Origin of The Concept |',
#   'Tags': ['#sciencewithsam', '#tamilquantum', '#quantumlecture'],
#   'Thumbnail': 'https://i.ytimg.com/vi/qK3WhbtnYiE/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-09-22T13:31:12Z',
#   'Duration': 'PT17M54S',
#   'Views': '1392',
#   'Likes': '69',
#   'Comments': '19',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'u8Taq7BftzI',
#   'Title': 'Quantum Mechanics Lecture - 6 | ஐன்ஸ்டீனை நெருடிய Electron Spin Superposition | Spin States',
#   'Tags': ['#sciencewithsam', '#tamilquantum', '#quantumlecture'],
#   'Thumbnail': 'https://i.ytimg.com/vi/u8Taq7BftzI/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-09-19T15:37:18Z',
#   'Duration': 'PT17M47S',
#   'Views': '2213',
#   'Likes': '103',
#   'Comments': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'axyB8eJfA_g',
#   'Title': 'Quantum Mechanics Lecture - 6 | Superposition Contd. | Quantum Weirdness | குவாண்டம் விசித்திரம் |',
#   'Tags': ['#sciencewithsam',
#    '#quantumintamil',
#    '#tamillectures',
#    '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/axyB8eJfA_g/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-09-12T12:30:04Z',
#   'Duration': 'PT22M42S',
#   'Views': '2112',
#   'Likes': '109',
#   'Comments': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'jUuXuT8OCCc',
#   'Title': 'India Lands On The Moon | நிலவில் வெற்றி கொடி நாட்டியது இந்தியா ! Chandrayaan 3 Success |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/jUuXuT8OCCc/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-08-23T13:06:19Z',
#   'Duration': 'PT4M10S',
#   'Views': '3425',
#   'Likes': '328',
#   'Comments': '38',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'G2Hpsf6VjII',
#   'Title': 'Chandrayaan 3 Victory Sure | நிலவில் இறங்குகிறது இந்தியா | Luna-25 Lost The Race |',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/G2Hpsf6VjII/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-08-21T14:24:04Z',
#   'Duration': 'PT9M29S',
#   'Views': '5251',
#   'Likes': '261',
#   'Comments': '28',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'q7CCuy-z16w',
#   'Title': 'India vs Russia On Moon Landing |  Chandrayaan 3 vs Luna 25 | நிலவில் முதலில் இறங்க போவது யார் ?',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/q7CCuy-z16w/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-08-17T13:45:47Z',
#   'Duration': 'PT9M4S',
#   'Views': '17911',
#   'Likes': '349',
#   'Comments': '42',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '4OzQep0O188',
#   'Title': 'How To Get Post Doc Jobs?|Tamil | முனைவர் பட்டத்திற்கு பின் வெளிநாட்டில் வேலைக்கு செல்வது எப்படி?|',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/4OzQep0O188/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-08-04T13:49:29Z',
#   'Duration': 'PT12M28S',
#   'Views': '2672',
#   'Likes': '181',
#   'Comments': '42',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'NLt8jvfRzdE',
#   'Title': 'How To Study Physics? | Feynman Technique | அறிவியல் கற்பது எப்படி ? பெயின்மென் சொன்ன ஐடியா|',
#   'Tags': ['#sciencewithsam', '#feynman'],
#   'Thumbnail': 'https://i.ytimg.com/vi/NLt8jvfRzdE/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-08-02T12:03:01Z',
#   'Duration': 'PT10M8S',
#   'Views': '14337',
#   'Likes': '1013',
#   'Comments': '139',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'YlBN1q_C36g',
#   'Title': 'Pokhran Nuclear Test | National Technology Day 2023 | Vajpayee and Abdul Kalam | Operation Shakthi',
#   'Tags': ['nationaltechnologyday', 'india', 'sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YlBN1q_C36g/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-05-11T13:00:20Z',
#   'Duration': 'PT10M3S',
#   'Views': '3971',
#   'Likes': '183',
#   'Comments': '39',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'I8-ePNI1dOA',
#   'Title': 'Feynman Nobel Prize Story - 2 | Why Feynman hated Nobel Prize|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/I8-ePNI1dOA/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-05-03T13:00:14Z',
#   'Duration': 'PT10M15S',
#   'Views': '3097',
#   'Likes': '149',
#   'Comments': '20',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'lRsV8HPNmOs',
#   'Title': 'Feynman Nobel Prize Story | Quantum Electro Dynamics QED | Feynman நோபல் பரிசு வென்ற கதை|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/lRsV8HPNmOs/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-05-02T16:38:37Z',
#   'Duration': 'PT18M4S',
#   'Views': '7553',
#   'Likes': '356',
#   'Comments': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'BKeyxTrBbnY',
#   'Title': 'Quantum Mechanics Lecture - 5 | Superposition | Quantum Weirdness | குவாண்டம் விசித்திரம் |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/BKeyxTrBbnY/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-04-26T13:00:13Z',
#   'Duration': 'PT28M44S',
#   'Views': '3389',
#   'Likes': '151',
#   'Comments': '41',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'fK-9tNPZwl0',
#   'Title': 'SpaceX Starship Explodes | உலகின் மிக பெரிய ராக்கெட் வெடித்தது | Rocket to Mars | Elon Musk |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/fK-9tNPZwl0/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-04-20T14:30:42Z',
#   'Duration': 'PT5M8S',
#   'Views': '5115',
#   'Likes': '253',
#   'Comments': '35',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '3YLM4syCmm8',
#   'Title': 'Quantum Mechanics Lecture - 4 | Tamil | Photons | குவாண்டம் ஒரு  விசித்திரம் | Superposition |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/3YLM4syCmm8/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-04-12T14:11:46Z',
#   'Duration': 'PT30M49S',
#   'Views': '5703',
#   'Likes': '216',
#   'Comments': '54',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'j58-HbDWRww',
#   'Title': 'Quantum Mechanics Lecture - 3 | Tamil | Why We Need Complex Numbers?|',
#   'Tags': ['#Quantumtamil',
#    '#tamilscience',
#    '#tamillecture',
#    '#sciencelecture'],
#   'Thumbnail': 'https://i.ytimg.com/vi/j58-HbDWRww/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-04-06T13:00:34Z',
#   'Duration': 'PT23M27S',
#   'Views': '5482',
#   'Likes': '240',
#   'Comments': '42',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'hFwavrH8BLU',
#   'Title': 'Quantum Mechanics Lecture - 2 | Tamil | Linear and Nonlinear அர்த்தம் என்ன |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/hFwavrH8BLU/default.jpg',
#   'Descriptions': 'Original English Lecture Notes can be downloaded from the following page. \n\nhttps://ocw.mit.edu/courses/8-04-quantum-physics-i-spring-2016/download/',
#   'Published_Date': '2023-04-04T13:00:34Z',
#   'Duration': 'PT12M21S',
#   'Views': '9839',
#   'Likes': '351',
#   'Comments': '36',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'UfutXnYu7R8',
#   'Title': 'Quantum Mechanics Lecture - 1| Tamil | குவாண்டம் அறிவியலின் முன்னுரை |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/UfutXnYu7R8/default.jpg',
#   'Descriptions': 'Planning to cover an extended lectures related to Quantum Mechanics. This is Lecture Number 1 introducing the need for Quantum Mechanics.',
#   'Published_Date': '2023-03-29T13:30:18Z',
#   'Duration': 'PT16M27S',
#   'Views': '50518',
#   'Likes': '1855',
#   'Comments': '172',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'uQuwBs7RJHw',
#   'Title': 'Feynman And Atomic Bomb | அணுகுண்டு ஆராய்ச்சியில் விருப்பமில்லாமல் நுழைந்த கதை |',
#   'Tags': ['#feynman', '#sciencewithsam', '#tamilscience', '#sciencestory'],
#   'Thumbnail': 'https://i.ytimg.com/vi/uQuwBs7RJHw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-03-24T13:20:19Z',
#   'Duration': 'PT17M40S',
#   'Views': '3860',
#   'Likes': '239',
#   'Comments': '47',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'KpuRyc00_t0',
#   'Title': 'Temple Mermaid Is Fake - Science | கோயிலில் கிடைத்த கடற்கன்னி| உண்மையை உடைத்த அறிவியல் | Japan |',
#   'Tags': ['#sciencewithsam', '#japanmermaid'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KpuRyc00_t0/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-03-02T14:40:42Z',
#   'Duration': 'PT6M2S',
#   'Views': '3132',
#   'Likes': '174',
#   'Comments': '27',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Title': 'National Science Day 2023 | Raman | Interesting Facts About Sir C V Raman |',
#   'Tags': ['nationalscienceday', 'raman', 'tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/E5O7Nx6lpu0/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-02-28T15:39:46Z',
#   'Duration': 'PT6M49S',
#   'Views': '1767',
#   'Likes': '137',
#   'Comments': '35',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'qIyIA68T1FY',
#   'Title': 'Feynman In Princeton | Tamil | முதன் முதலில் ஐன்ஸ்டீன் சந்தித்த போது | Feynman Life Story Full |',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/qIyIA68T1FY/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-02-06T13:30:30Z',
#   'Duration': 'PT21M6S',
#   'Views': '5321',
#   'Likes': '263',
#   'Comments': '39',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'PoS7ifimbpk',
#   'Title': '#kalpanachawla #anniversary Meaning of her name #shortstory #tamilscience',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/PoS7ifimbpk/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-02-01T07:31:58Z',
#   'Duration': 'PT1M',
#   'Views': '3310',
#   'Likes': '261',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'NlvuPsZtQJw',
#   'Title': 'Feynman College Life in MIT| Tamil| Feynmanயிடம் MIT கேட்ட கேள்விகள்| Feynman கல்லூரி வாழ்க்கை|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/NlvuPsZtQJw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-01-26T15:29:39Z',
#   'Duration': 'PT14M29S',
#   'Views': '4803',
#   'Likes': '273',
#   'Comments': '32',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'UaBKxzBhdqk',
#   'Title': 'How To Publish Research Article?|Tamil |ஆராய்ச்சி கட்டுரைகள் எழுதுவது எப்படி?| தமிழில் எழுதலாமா?',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/UaBKxzBhdqk/default.jpg',
#   'Descriptions': 'அறிவியல் ஆய்வு கட்டுரைகளை பிரசுரிக்கும் நிறுவனங்களின்  தொகுப்பை கீழ்காணும் இணையத்தளத்தில்  காணலாம்.\n\nhttps://www.publishersglobal.com/directory/subject/science-publishers/4/\n\nஅறிவியல் ஆய்வு தலைப்புகளை பற்றி தேட கீழுள்ள இணையத்தை பயன்படுத்தலாம் \n\nwww.scholar.google.com',
#   'Published_Date': '2023-01-18T13:47:39Z',
#   'Duration': 'PT12M2S',
#   'Views': '4817',
#   'Likes': '240',
#   'Comments': '53',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'mRBCCWoK2Qw',
#   'Title': 'ஒட்டிக்கோ கட்டிக்கோ வேட்டிக்கு  பின்னால் உள்ள அறிவியல் | Velcro Story | Tamil | Ramraj Dhotis |',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/mRBCCWoK2Qw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-01-16T09:13:49Z',
#   'Duration': 'PT10M25S',
#   'Views': '2056',
#   'Likes': '153',
#   'Comments': '46',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'd4Cz8Vcg3tY',
#   'Title': '#HappyPongal #tamilnadu #தமிழ்நாடு #ScienceWithSam',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/d4Cz8Vcg3tY/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-01-15T14:51:38Z',
#   'Duration': 'PT59S',
#   'Views': '1870',
#   'Likes': '218',
#   'Comments': '31',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'hoJw8D4DrLc',
#   'Title': 'Story of English Calendar | Tamil | Happy New Year to You All | THANK YOU |',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/hoJw8D4DrLc/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2023-01-01T11:30:10Z',
#   'Duration': 'PT8M22S',
#   'Views': '2687',
#   'Likes': '211',
#   'Comments': '46',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'uob4vPknXkI',
#   'Title': 'Happy New Year Dear Friends from  #ScienceWithSam #happynewyear2023',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/uob4vPknXkI/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-12-31T20:34:32Z',
#   'Duration': 'PT1M',
#   'Views': '1716',
#   'Likes': '239',
#   'Comments': '48',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'fnnqJ_COroo',
#   'Title': 'Richard Feynman Life Story - 2 | தங்கையை விஞ்ஞானி ஆக்கிய சிறுவன் Feynman |',
#   'Tags': ['#sciencewithsam', '#feynmanlife', '#scientiststoryintamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/fnnqJ_COroo/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-12-28T12:30:14Z',
#   'Duration': 'PT11M23S',
#   'Views': '3497',
#   'Likes': '222',
#   'Comments': '33',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'uj2t-A2zACM',
#   'Title': 'Richard Feynman Life - 1| Tamil | ரிச்சர்ட் ஃபயின்மன் வாழ்க்கை - பகுதி 1 | குழந்தை & பள்ளி பருவம்|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/uj2t-A2zACM/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-12-24T15:05:17Z',
#   'Duration': 'PT15M1S',
#   'Views': '4833',
#   'Likes': '317',
#   'Comments': '70',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'UmCb-7mNREE',
#   'Title': 'National Day of Mathematics #Ramanujan #mathsgenius',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/UmCb-7mNREE/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-12-22T17:18:27Z',
#   'Duration': 'PT34S',
#   'Views': '2832',
#   'Likes': '259',
#   'Comments': '19',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'mMpvW8cZDwo',
#   'Title': 'Richard Feynman | Tamil | அறிவியல் வித்தகன் | More Than A Genius |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/mMpvW8cZDwo/default.jpg',
#   'Descriptions': 'To watch the video how Feynman explained the science of fire, check out the following link \n\nhttps://www.youtube.com/watch?v=3B_nkzvU_XQ',
#   'Published_Date': '2022-12-08T07:14:47Z',
#   'Duration': 'PT13M32S',
#   'Views': '12817',
#   'Likes': '672',
#   'Comments': '88',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'N6ZV9jPQok0',
#   'Title': 'Last Men on The Moon - Apollo 17 50 Years Anniversary | மனிதன் கடைசியாக நிலவிற்கு சென்ற நாள் இன்று |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/N6ZV9jPQok0/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-12-07T13:44:24Z',
#   'Duration': 'PT3M7S',
#   'Views': '1128',
#   'Likes': '81',
#   'Comments': '30',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'RPfhLGAKK3Q',
#   'Title': 'How To Become An Astronaut | Tamil | விண்வெளி வீரர் ஆவது எப்படி ? |',
#   'Tags': ['#sciencewithsam', '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RPfhLGAKK3Q/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-12-05T12:43:13Z',
#   'Duration': 'PT12M45S',
#   'Views': '13164',
#   'Likes': '596',
#   'Comments': '57',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'ruxVRaCchtI',
#   'Title': 'Walk Backwards - Scientists #exercise #tamilscience',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ruxVRaCchtI/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-12-03T06:14:08Z',
#   'Duration': 'PT1M2S',
#   'Views': '1759',
#   'Likes': '128',
#   'Comments': '25',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '85aiJYOdK_w',
#   'Title': 'Apollo Artemis - Moon Mission | Name Meaning | Tamil | Why These Greek Names |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/85aiJYOdK_w/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-11-17T13:30:39Z',
#   'Duration': 'PT5M35S',
#   'Views': '2334',
#   'Likes': '150',
#   'Comments': '20',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'qqb3HazZLMs',
#   'Title': 'Moon Launch Success | Artemis 1 I Most powerful rocket launched |Tamil | Back to Moon',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/qqb3HazZLMs/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-11-16T16:39:20Z',
#   'Duration': 'PT5M29S',
#   'Views': '3608',
#   'Likes': '203',
#   'Comments': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '6yIDo13llWQ',
#   'Title': "Why Aliens Don't Visit Earth ?| Tamil | ஏலியன்கள் ஏன் இதுவரை பூமிக்கு வரவில்லை |",
#   'Tags': ['tamilscience', 'aliens', 'sciencenews', 'space'],
#   'Thumbnail': 'https://i.ytimg.com/vi/6yIDo13llWQ/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-11-11T12:30:03Z',
#   'Duration': 'PT12M35S',
#   'Views': '21875',
#   'Likes': '764',
#   'Comments': '119',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'G6Zvjkz_hSM',
#   'Title': 'Aristotle and Dolphins #tamilscience #sciencestory #sciencefacts #sciencewithSam #unknownscience',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/G6Zvjkz_hSM/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-11-07T04:20:40Z',
#   'Duration': 'PT1M1S',
#   'Views': '4196',
#   'Likes': '391',
#   'Comments': '19',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '1Vtr7-kWB4I',
#   'Title': 'Nothing new in Physics, Mr. Planck #shorts #sciencewithSam #tamilscience #sciencefacts',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1Vtr7-kWB4I/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-11-01T08:26:42Z',
#   'Duration': 'PT39S',
#   'Views': '7859',
#   'Likes': '817',
#   'Comments': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'tjRZK_1XAro',
#   'Title': 'Nobel Prize is not important - Feynman about Nobel Prize #shorts #feynman #sciencewithSam',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/tjRZK_1XAro/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-10-28T12:00:07Z',
#   'Duration': 'PT49S',
#   'Views': '5193',
#   'Likes': '544',
#   'Comments': '40',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'mieGqJ0BXiE',
#   'Title': '#shorts #sciencewithSam #thankyou',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/mieGqJ0BXiE/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-10-28T04:13:15Z',
#   'Duration': 'PT1M',
#   'Views': '2508',
#   'Likes': '350',
#   'Comments': '24',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'rggw1Izwbf0',
#   'Title': 'Big Bang never happened?',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/rggw1Izwbf0/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-10-27T13:03:04Z',
#   'Duration': 'PT36S',
#   'Views': '2672',
#   'Likes': '228',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'wk30gfF_C_w',
#   'Title': 'Bell Inequality | In Simple Tamil | 2022 Physics Nobel Prize in Tamil | 2022 நோபல் பரிசின் அறிவியல்|',
#   'Tags': ['#nobelprize', '#tamilscience'],
#   'Thumbnail': 'https://i.ytimg.com/vi/wk30gfF_C_w/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-10-21T10:46:54Z',
#   'Duration': 'PT18M41S',
#   'Views': '26416',
#   'Likes': '879',
#   'Comments': '168',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'w8D181wzNAE',
#   'Title': '2022 Physics Nobel Prize | Tamil | Quantum Entanglement | 2022 இயற்பியல் நோபல் பரிசு | Quick Update',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/w8D181wzNAE/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-10-04T10:47:34Z',
#   'Duration': 'PT11M17S',
#   'Views': '27899',
#   'Likes': '1220',
#   'Comments': '182',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'Rsv1Gee1X3k',
#   'Title': 'Big Bang Is Wrong? | Big Bang Never Happened? | உண்மை என்ன? | பெரு வெடிப்பு என்ற ஒன்றே இல்லை? |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Rsv1Gee1X3k/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-09-09T12:30:08Z',
#   'Duration': 'PT18M53S',
#   'Views': '33822',
#   'Likes': '1213',
#   'Comments': '192',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'Uug8GbypVeE',
#   'Title': 'Wireless Power Transmission Record | Wire இல்லாமல் மின்சாரம் கடத்தி விஞ்ஞானிகள் சாதனை |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Uug8GbypVeE/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-09-07T12:30:09Z',
#   'Duration': 'PT8M27S',
#   'Views': '69245',
#   'Likes': '1478',
#   'Comments': '111',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'w-skmswzslw',
#   'Title': 'First Exoplanet Image by James Webb Telescope | Tamil | வேற்று கிரகத்தின் முதல் படம் |',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/w-skmswzslw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-09-02T14:07:03Z',
#   'Duration': 'PT7M35S',
#   'Views': '37440',
#   'Likes': '810',
#   'Comments': '47',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '-WCqyL_maXw',
#   'Title': 'Carbon Dioxide In Exoplanet | First Time Confirmed | Tamil | James Webb Telescope New Discovery |',
#   'Tags': ['#tamilexoplanet', '#tamilscience', '#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-WCqyL_maXw/default.jpg',
#   'Descriptions': 'To learn how spectroscopy helps to find the chemicals of distant stars, galaxies and exoplanets, check out my video using the link below\n\nhttps://www.youtube.com/watch?v=0F9yBSVORiw',
#   'Published_Date': '2022-08-26T13:48:59Z',
#   'Duration': 'PT9M43S',
#   'Views': '12094',
#   'Likes': '400',
#   'Comments': '39',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'IkUnfZ3DZ5E',
#   'Title': 'Black Hole Sound Released | Tamil | மரண ஓலமா? ஓம் சத்தமா? | உண்மை என்ன? |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/IkUnfZ3DZ5E/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-08-25T12:30:12Z',
#   'Duration': 'PT6M14S',
#   'Views': '24121',
#   'Likes': '860',
#   'Comments': '127',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'UMJNo2AsBIw',
#   'Title': 'உலகின் நீளமான டைனோசர் கால் தடங்கள் கண்டுபிடிப்பு | 11.3 Crore Old Dinosaur Footprints Found |',
#   'Tags': ['#dinosaur', '#tamildinosaur', '#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/UMJNo2AsBIw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-08-24T13:00:27Z',
#   'Duration': 'PT5M45S',
#   'Views': '2973',
#   'Likes': '186',
#   'Comments': '29',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'GzsO5iDWFzE',
#   'Title': 'Einstein General Theory Equation Explained| Tamil | Spacetime Mathematics| Field Equation Meaning|',
#   'Tags': ['#Einsteinspacetime',
#    '#spacetime',
#    '#generaltheory',
#    '#relativity'],
#   'Thumbnail': 'https://i.ytimg.com/vi/GzsO5iDWFzE/default.jpg',
#   'Descriptions': 'Sorry for the poor audio quality in the second part of the video. I will try to avoid this in the future. \n\nYou can check out my video on Einstein greatest blunder using the link below. \n\nhttps://www.youtube.com/watch?v=wQtxHEpWtLc. \n\nAlso previous two videos on the concept of spacetime, check out the videos using the following links\n\nhttps://www.youtube.com/watch?v=OsxGwNSqsoQ   - What is spacetime?\n\nhttps://www.youtube.com/watch?v=JIfhCzk0Qe0       - Spacetime curvature and gravity relation',
#   'Published_Date': '2022-08-19T12:30:05Z',
#   'Duration': 'PT21M6S',
#   'Views': '20668',
#   'Likes': '780',
#   'Comments': '148',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '0F9yBSVORiw',
#   'Title': 'Chemicals of Stars and Galaxies - அறிவது எப்படி?| தூர காலக்ஸியில் வேதி பொருட்களை அறிவது எப்படி?',
#   'Tags': ['#sciencewithsam',
#    '#jameswebbtamil',
#    '#tamilastronomy',
#    '#spectroscopy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/0F9yBSVORiw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-07-15T11:30:00Z',
#   'Duration': 'PT20M28S',
#   'Views': '12920',
#   'Likes': '582',
#   'Comments': '133',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '0m_GL1s48PM',
#   'Title': 'James Webb Telescope Five New Images | Tamil | ஐந்து முக்கிய புகைப்படங்கள்| மனித இனம் கண்டிராதது|',
#   'Tags': ['#tamilscience',
#    '#tamiljameswebb',
#    '#jameswebbtelescope',
#    '#spacetamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/0m_GL1s48PM/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-07-12T17:05:40Z',
#   'Duration': 'PT11M31S',
#   'Views': '67494',
#   'Likes': '2929',
#   'Comments': '223',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'SahrxeFDOTU',
#   'Title': 'James Webb Telescope First Image| Tamil | ஆதி பிரபஞ்சத்தின் முதல் படம்|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/SahrxeFDOTU/default.jpg',
#   'Descriptions': 'Sorry for reupload. Previous version had some quality issues. So I am uploading with better quality. Thanks',
#   'Published_Date': '2022-07-12T04:28:01Z',
#   'Duration': 'PT6M16S',
#   'Views': '12632',
#   'Likes': '551',
#   'Comments': '58',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'cklmbSyiDWw',
#   'Title': 'What is Cloudburst? | Tamil | Amarnath Accident | மேகவெடிப்பு என்றால் என்ன ?',
#   'Tags': ['#sciencewithsam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/cklmbSyiDWw/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2022-07-09T06:11:07Z',
#   'Duration': 'PT9M18S',
#   'Views': '14433',
#   'Likes': '437',
#   'Comments': '50',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
# ...
#   'Title': '24. Artificial Sun | Tamil | Tokamak, ITER, Fusion power generation',
#   'Tags': ['ITER', 'Tokamak', 'China', 'India'],
#   'Thumbnail': 'https://i.ytimg.com/vi/iz8Rh9HCutc/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2020-12-11T10:32:57Z',
#   'Duration': 'PT19M47S',
#   'Views': '10615',
#   'Likes': '418',
#   'Comments': '38',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'pajRi7pt0C0',
#   'Title': '23. Quantum Physics History | Tamil | How it all started !? - Story of Quantum Scientists !!',
#   'Tags': ['Quantum mechanics', 'Einstein', 'Schrodinger'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pajRi7pt0C0/default.jpg',
#   'Descriptions': 'This video does not describe in detail any science of Quantum Physics. This video just takes you through the journey of how Quantum Physics started in the 19th century. This video gives some interesting facts about scientists involved in this amazing journey.',
#   'Published_Date': '2020-11-29T23:00:07Z',
#   'Duration': 'PT23M13S',
#   'Views': '19823',
#   'Likes': '688',
#   'Comments': '58',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'Nykz9_Vh2Bo',
#   'Title': '22. What is Cyclone | Simple Tamil | Cyclone Name meaning',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Nykz9_Vh2Bo/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2020-11-26T07:13:09Z',
#   'Duration': 'PT14M43S',
#   'Views': '2456',
#   'Likes': '126',
#   'Comments': '16',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'zcvArp8CSrk',
#   'Title': '21. Keeladi & Nanotechnology - Scientific truth | Tamil | கீழடி தமிழர்கள் நானோ விஞ்ஞானிகளா !?',
#   'Tags': ['Keeladi', 'Tamil Culture', 'CNT'],
#   'Thumbnail': 'https://i.ytimg.com/vi/zcvArp8CSrk/default.jpg',
#   'Descriptions': 'Misconception on the recent research work on Carbon Nano Tubes found in Keeladi, Tamilnadu, India. The nanostructures found in Keeladi is the oldest nanostructures found in the world so far. That does not mean ancient Tamil people were nano experts. This video tries to clarify such misconception.',
#   'Published_Date': '2020-11-24T18:25:55Z',
#   'Duration': 'PT20M2S',
#   'Views': '1717',
#   'Likes': '101',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'DUxNSZg95m8',
#   'Title': '20. Bladeless fan | Tamil | How does it work? Science behind !!',
#   'Tags': ['Bladeless fan', 'air multiplier', 'dyson fan'],
#   'Thumbnail': 'https://i.ytimg.com/vi/DUxNSZg95m8/default.jpg',
#   'Descriptions': 'Science behind Air Multiplier or so called Bladeless Fan !!',
#   'Published_Date': '2020-11-20T23:00:02Z',
#   'Duration': 'PT7M35S',
#   'Views': '11171',
#   'Likes': '544',
#   'Comments': '38',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'VPdRgL9Wlho',
#   'Title': '19. Keeladi Carbon Nano Tubes | Tamil | Oldest Nanostructure in the world !!',
#   'Tags': ['Keeladi', 'Carbon nanotube', 'CNT'],
#   'Thumbnail': 'https://i.ytimg.com/vi/VPdRgL9Wlho/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2020-11-19T19:42:04Z',
#   'Duration': 'PT9M39S',
#   'Views': '3106',
#   'Likes': '201',
#   'Comments': '30',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'MYEpZs9zqFQ',
#   'Title': '18. Laser eye surgery | Tamil | How does it work? |',
#   'Tags': ['Lasik', 'laser surgery', 'laser', 'eye surgery'],
#   'Thumbnail': 'https://i.ytimg.com/vi/MYEpZs9zqFQ/default.jpg',
#   'Descriptions': 'Video describes the science behind how lasers help in eye surgery !!',
#   'Published_Date': '2020-11-16T23:00:04Z',
#   'Duration': 'PT11M19S',
#   'Views': '15520',
#   'Likes': '496',
#   'Comments': '84',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'QYUdzoW8Ecw',
#   'Title': '17. Nehru and Indian Science (In Tamil)',
#   'Tags': ['Nehru', 'Bhabha', 'Vikram Sarabhai'],
#   'Thumbnail': 'https://i.ytimg.com/vi/QYUdzoW8Ecw/default.jpg',
#   'Descriptions': 'இந்திய அறிவியல் தொழில்நுட்பத்திற்கு நேருவின் பங்களிப்பு !!',
#   'Published_Date': '2020-11-14T03:00:03Z',
#   'Duration': 'PT19M42S',
#   'Views': '1386',
#   'Likes': '61',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'rkt_wMoIz3U',
#   'Title': '16. Big Bang & Before the Big Bang | Tamil | What happened before the big bang? |',
#   'Tags': ['Big bang', 'Inflation', 'universe', 'sciencewithsam', 'CMB'],
#   'Thumbnail': 'https://i.ytimg.com/vi/rkt_wMoIz3U/default.jpg',
#   'Descriptions': 'What science tells us during the big bang and before the big bang ? Explained in simple Tamil !!',
#   'Published_Date': '2020-11-07T11:32:26Z',
#   'Duration': 'PT22M18S',
#   'Views': '91017',
#   'Likes': '2311',
#   'Comments': '321',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': '7pp90cY3cws',
#   'Title': "15. Nehru's role in Indian Science And Technology !!",
#   'Tags': ['Nehru', 'ISRO', 'BARC', 'Bhabha', 'Vikram Sarabhai', 'IITs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/7pp90cY3cws/default.jpg',
#   'Descriptions': "After India's independence, contribution of Nehru for India's Science is immense. His vision and passion for science has resulted in various internationally famous organizations such as ISRO, BARC, IITs, AIIMS, TIFT, NPL and so on. Its important for the young generations to be aware of what this great visionary has contributed to India so that we are proud as a nation today in international scientific community !!",
#   'Published_Date': '2020-11-01T03:00:01Z',
#   'Duration': 'PT17M2S',
#   'Views': '3057',
#   'Likes': '72',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'jLxX9QCf3zs',
#   'Title': '14. God Particle - Higgs Boson | Simple Tamil |',
#   'Tags': ['God particle',
#    'Higgs Boson',
#    'Tamil Science',
#    'Peter Higgs',
#    'Einstein',
#    'Nobel Prize'],
#   'Thumbnail': 'https://i.ytimg.com/vi/jLxX9QCf3zs/default.jpg',
#   'Descriptions': 'Story behind Higgs field, often called as Higgs Boson !! And its Physics and significance !!\n\nI made a small mistake in this video when I try to mention why its called God particle. The real reason is it was originally called as Goddamn particle because of the difficulty in finding this. So the reason I gave in this video is wrong.  My apologies. Thanks',
#   'Published_Date': '2020-10-30T09:30:52Z',
#   'Duration': 'PT20M24S',
#   'Views': '46772',
#   'Likes': '1595',
#   'Comments': '248',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'lGUocqYnDtQ',
#   'Title': '13. Time Travel & Wormhole (In Tamil) - Simple explanation !',
#   'Tags': ['Wormhole', 'timetravel', 'einstein'],
#   'Thumbnail': 'https://i.ytimg.com/vi/lGUocqYnDtQ/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2020-10-22T09:37:10Z',
#   'Duration': 'PT18M56S',
#   'Views': '38203',
#   'Likes': '1258',
#   'Comments': '119',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'wQtxHEpWtLc',
#   'Title': "12. Einstein's Greatest blunder (In Tamil) -  ஐன்ஸ்டீனின் மிக பெரிய தவறு ! கதையும் அறிவியலும் !",
#   'Tags': ['einstein',
#    'tamil science',
#    'greatest blunder',
#    'science with sam'],
#   'Thumbnail': 'https://i.ytimg.com/vi/wQtxHEpWtLc/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2020-10-15T07:05:41Z',
#   'Duration': 'PT15M1S',
#   'Views': '7466',
#   'Likes': '434',
#   'Comments': '53',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'J0j9KPDjPXI',
#   'Title': '11. Black hole (In simple Tamil) - Interesting story behind 2020 Nobel Prize in Physics',
#   'Tags': ['Newton',
#    'einstein',
#    'black hole',
#    'Science with sam',
#    'nobel prize',
#    'physics',
#    'gravity'],
#   'Thumbnail': 'https://i.ytimg.com/vi/J0j9KPDjPXI/default.jpg',
#   'Descriptions': 'Interesting story behind the discovery of black hole and eventual Nobel prize for Physics in 2020 - Summarized in Tamil language.',
#   'Published_Date': '2020-10-08T20:56:31Z',
#   'Duration': 'PT16M13S',
#   'Views': '14531',
#   'Likes': '594',
#   'Comments': '83',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'vhKlZIV_9Lg',
#   'Title': '10. 2020 Nobel prize in Physics (in Tamil) - Short and quick update !',
#   'Tags': ['blackhole',
#    'science',
#    'Nobel Prize',
#    'Physics',
#    'Black Hole',
#    'Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/vhKlZIV_9Lg/default.jpg',
#   'Descriptions': 'Black hole and 2020 Physics Nobel Prize for Black hole ! Brief and amateur explanation in Tamil language !',
#   'Published_Date': '2020-10-06T13:34:52Z',
#   'Duration': 'PT6M34S',
#   'Views': '2325',
#   'Likes': '140',
#   'Comments': '16',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'X6Zgh_Ww9qk',
#   'Title': '9. How to read Prague Astronomical Clock (In Tamil language)',
#   'Tags': ['Prague', 'Astronomical Clock'],
#   'Thumbnail': 'https://i.ytimg.com/vi/X6Zgh_Ww9qk/default.jpg',
#   'Descriptions': 'Explaining how to read various times and signs in Astronomical Clock located in Prague',
#   'Published_Date': '2020-10-05T04:38:08Z',
#   'Duration': 'PT2M36S',
#   'Views': '612',
#   'Likes': '42',
#   'Comments': '4',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'pHVUjoiC8ts',
#   'Title': '8. Famous Prague Astronomical Clock - Features (In Tamil)',
#   'Tags': ['Prague',
#    'Astronomical Clock',
#    'Amazing Science in Tamil',
#    'Tamil Science',
#    'Science in Tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pHVUjoiC8ts/default.jpg',
#   'Descriptions': 'Amazing features of world famous Prague Astronomical Clock explained in Tamil language !',
#   'Published_Date': '2020-10-04T19:40:55Z',
#   'Duration': 'PT7M12S',
#   'Views': '990',
#   'Likes': '74',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'mFbIdGkmGQ0',
#   'Title': "7. Laser tattoo removal (In Tamil) - It's science - பச்சை குத்துவதை அழிக்கும் லேசரின் அறிவியல் !!",
#   'Tags': ['science', 'laser', 'tattoo', 'tattoo removal'],
#   'Thumbnail': 'https://i.ytimg.com/vi/mFbIdGkmGQ0/default.jpg',
#   'Descriptions': 'பச்சை குத்தும் அறிவியல் என்ன ? அதை அழிக்கும் லேசரின் அறிவியல் என்ன ? சுருக்கமாக, எளிமையாக !',
#   'Published_Date': '2020-09-19T09:07:06Z',
#   'Duration': 'PT5M17S',
#   'Views': '16132',
#   'Likes': '377',
#   'Comments': '56',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'CK-Z2H23aNY',
#   'Title': '6. Age of The Earth (In Tamil) - Interesting story !!',
#   'Tags': ['Science',
#    'Tamil Science',
#    'Science In tamil',
#    'age of the earth',
#    'Earth',
#    'Universe',
#    'Nature',
#    'Kelvin'],
#   'Thumbnail': 'https://i.ytimg.com/vi/CK-Z2H23aNY/default.jpg',
#   'Descriptions': "Simplified explanation about Earth's age in Tamil language.",
#   'Published_Date': '2020-09-08T20:44:43Z',
#   'Duration': 'PT11M44S',
#   'Views': '6069',
#   'Likes': '303',
#   'Comments': '60',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'r4atlpx48Ow',
#   'Title': '5. Kalam & Einstein  (Tamil) - Teachers day special',
#   'Tags': ['Teachers Day', 'Abdul Kalam', 'Albert Einstein'],
#   'Thumbnail': 'https://i.ytimg.com/vi/r4atlpx48Ow/default.jpg',
#   'Descriptions': 'ஆசிரியர் தின நல்வாழ்த்துக்கள் !! கலாம் மற்றும் ஐன்ஸ்டீன் இருவரின் வாழ்க்கையில் இரண்டு வகையான ஆசிரியர்கள் பற்றி சுருக்கமாக !!',
#   'Published_Date': '2020-09-04T17:47:01Z',
#   'Duration': 'PT8M5S',
#   'Views': '2318',
#   'Likes': '135',
#   'Comments': '15',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'o2YAzhcnN30',
#   'Title': '4. C.V. Raman & K. S. Krishnan Vs Russians! (In Tamil)',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/o2YAzhcnN30/default.jpg',
#   'Descriptions': 'ரஷ்யா விஞ்ஞானிகளை வென்று, நோபல் பரிசை பெற்ற ராமனின் சுவாரியசமான தகவல்கள் !! உலகம் மறந்த கிருஷ்ணன் !!',
#   'Published_Date': '2020-08-30T09:22:41Z',
#   'Duration': 'PT13M58S',
#   'Views': '2425',
#   'Likes': '135',
#   'Comments': '23',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'cFd0i4UyPpU',
#   'Title': '3. Tamil Motivational Talk | Science and Curiosity',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/cFd0i4UyPpU/default.jpg',
#   'Descriptions': 'மாணவர்களுக்கு அறிவியலின் ஆர்வத்தை தூண்டும் வண்ணம் சுவாரியசமாக அறிவியலை எப்படி படிக்கலாம் என்கிற நோக்கில் வழங்கப்பட்ட உரை !!',
#   'Published_Date': '2020-08-24T08:10:17Z',
#   'Duration': 'PT37M19S',
#   'Views': '4688',
#   'Likes': '315',
#   'Comments': '58',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'sAuoNwN2qMU',
#   'Title': '2. Raman effect (In simple Tamil)',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/sAuoNwN2qMU/default.jpg',
#   'Descriptions': '',
#   'Published_Date': '2020-08-23T20:44:50Z',
#   'Duration': 'PT10M21S',
#   'Views': '12318',
#   'Likes': '527',
#   'Comments': '73',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Video_Id': 'rFnCy_tn5Lo',
#   'Title': '1. Corona Vaccine (In Tamil)',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/rFnCy_tn5Lo/default.jpg',
#   'Descriptions': 'கொரோனா\xa0மருந்து எப்படி வேலை செய்யும்\xa0? ஏன் கண்டுபிடிக்க தாமதம் ?',
#   'Published_Date': '2020-08-20T20:50:52Z',
#   'Duration': 'PT10M17S',
#   'Views': '1227',
#   'Likes': '91',
#   'Comments': '20',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
len(video_details)
# Out:
# 276

# %%
#get comment information

def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50)
            response=request.execute()

            for item in response['items']:
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                
                Comment_data.append(data)
    except:
        pass
    return Comment_data

# %%
Comment_details=get_comment_info(Video_Ids)

# %%
Comment_details
# Out:
# [{'Comment_Id': 'Ugxn2JPIZVemPp9E8254AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Who is John Bernoulli &#39;s and l hospital',
#   'Comment_Author': '@ts-kl5ld',
#   'Comment_Published': '2024-10-30T13:08:43Z'},
#  {'Comment_Id': 'Ugxr8OCpy6R0fr1tMs94AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Thank younka sir useful video your voice nice unga contact number kudunga pls',
#   'Comment_Author': '@prakashperiyasamy2500',
#   'Comment_Published': '2024-10-27T04:15:29Z'},
#  {'Comment_Id': 'UgySVNqwlZi8DarnvSF4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Sir please make a video about three body problem.',
#   'Comment_Author': '@samuelsanthoshkumar5797',
#   'Comment_Published': '2024-10-22T07:46:54Z'},
#  {'Comment_Id': 'UgzoR_t5AeNhyyrRGup4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'சிறந்த introduction.\r<br>\r<br>குதர்க்கமாக கேட்கிறேன் என்று நினைக்க வேண்டாம்.\r<br>Simple Permutation &amp; Combination கணிதம் மூலம் 20 protein combination கண்டு பிடிக்க முடியாதா?<br><br>Asking for the sake of discussion.',
#   'Comment_Author': '@victorsubbiah6077',
#   'Comment_Published': '2024-10-19T17:01:00Z'},
#  {'Comment_Id': 'Ugxah3ldXn0kxmC9ZPh4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Super sir',
#   'Comment_Author': '@SivaganeshD-x8j',
#   'Comment_Published': '2024-10-16T16:58:04Z'},
#  {'Comment_Id': 'UgxpadpzUnJGqDLzehJ4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Quantum electrodynamics antha topic Pathi pesunga humble request',
#   'Comment_Author': '@AshokKumar-ts8gf',
#   'Comment_Published': '2024-10-15T18:00:15Z'},
#  {'Comment_Id': 'UgzX8zNdkoMjs6Zu-hB4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Informative video Dr. Sam sir. Good work.',
#   'Comment_Author': '@palanisamin3210',
#   'Comment_Published': '2024-10-14T16:09:47Z'},
#  {'Comment_Id': 'Ugw90QT_zUk_nj9B5b94AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'மேற்கத்திய நாடுகளில் அறிவியல் மதத்திலிருந்து விடுபட்டதால்தான் நோபல் பரிசினைப் பெறுகின்றன. நம் நாடு மத மூடநம்பிக்கைகளில் மூழ்கிக் கிடப்பதால்....',
#   'Comment_Author': '@gopalsamykannan2964',
#   'Comment_Published': '2024-10-12T05:59:31Z'},
#  {'Comment_Id': 'Ugz3Xd9aVWVhkNp7klR4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Thanks!',
#   'Comment_Author': '@ThankyouMarkHughes',
#   'Comment_Published': '2024-10-10T01:28:19Z'},
#  {'Comment_Id': 'Ugws6O3IWVdm87uNIY54AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'good',
#   'Comment_Author': '@PaalSaanScienceAndTech',
#   'Comment_Published': '2024-10-09T17:57:41Z'},
#  {'Comment_Id': 'UgzZzKaLDVGSxukbUgB4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'மருத்துவத்திற்கான நோபல் பரிசு 2024 - பற்றி வீடியோ போடுங்கள் சார்.',
#   'Comment_Author': '@janarthjana2014',
#   'Comment_Published': '2024-10-09T16:38:10Z'},
#  {'Comment_Id': 'UgwXPTqJhg3tCae_ztl4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Welcome back sir❤',
#   'Comment_Author': '@ayyappanmanikandan4593',
#   'Comment_Published': '2024-10-09T15:58:31Z'},
#  {'Comment_Id': 'Ugx29R-aiG5yzvgkmCR4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'ஆழ்ந்த அறிவுக்கும் அயராத உழைப்புக்கும் நோபல் பரிசு பெற்ற ஜாம்பவான்களுக்கு எனது மனமார்ந்த வாழ்த்துக்கள்',
#   'Comment_Author': '@safeenasatheek3498',
#   'Comment_Published': '2024-10-09T15:29:07Z'},
#  {'Comment_Id': 'UgwLEFYALD7KCcN7YpJ4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': '🎉🎉👌👌',
#   'Comment_Author': '@karthickeyan6603',
#   'Comment_Published': '2024-10-09T14:51:57Z'},
#  {'Comment_Id': 'UgxLnltXi5qTBzsB1El4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'This concept looks like &quot;molecular docking &quot; is it correct sir?',
#   'Comment_Author': '@HiiiByiii',
#   'Comment_Published': '2024-10-09T14:44:02Z'},
#  {'Comment_Id': 'UgyWSn6PjQKc1Tv3amN4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Thank you sir ❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-10-09T14:22:57Z'},
#  {'Comment_Id': 'UgwFgmRgiBkFHtAyDEt4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Good video',
#   'Comment_Author': '@venkatesank7785',
#   'Comment_Published': '2024-10-09T14:06:00Z'},
#  {'Comment_Id': 'UgzwaixY0LpFDzc0xYl4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'நன்றி',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2024-10-09T13:46:44Z'},
#  {'Comment_Id': 'Ugxj-i3_E6nFhgsEb3d4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Computational protein structure 🤩. Seeing our research field getting nobel prize motivates us to study even more. Thank you sir for current updates in science',
#   'Comment_Author': '@indumathik6108',
#   'Comment_Published': '2024-10-09T13:38:31Z'},
#  {'Comment_Id': 'UgxZttOnLlALKuY02h54AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': 'Welcome back🎉bro',
#   'Comment_Author': '@RajiniS-om2jd',
#   'Comment_Published': '2024-10-09T13:37:06Z'},
#  {'Comment_Id': 'UgzLWSjcs55-SrIzezF4AaABAg',
#   'Video_Id': 'jTvSZOHhDzA',
#   'Comment_Text': '<a href="UCkszU2WH9gy1mb0dV-11UJg/EvkfY6uNC5OykQOewoCQAQ"></a>',
#   'Comment_Author': '@darrelllyjo9162',
#   'Comment_Published': '2024-10-09T13:36:54Z'},
#  {'Comment_Id': 'UgzvkTcxv0brsSsCgTh4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thalaivan vera level.. ❤ plz weekly 2 video vathu uplaod sir😊',
#   'Comment_Author': '@risheerox8755',
#   'Comment_Published': '2024-10-24T18:52:52Z'},
#  {'Comment_Id': 'UgwYcB4EqMtuhJdA6EN4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Sir, please can you share the reference documents link on the description?',
#   'Comment_Author': '@Sangeetha-Persnl',
#   'Comment_Published': '2024-10-24T04:24:49Z'},
#  {'Comment_Id': 'Ugw8vmN3MsUSwneJA3p4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Vathi coming baby naan ungala rompa miss paane. Sorry😅 but thank you 🙏for everthing. Because umgalathan jee           advanced examla pass anne❤❤❤❤',
#   'Comment_Author': '@nmathiyalaganmarishwaran',
#   'Comment_Published': '2024-10-19T15:06:26Z'},
#  {'Comment_Id': 'Ugw26RSmAQN1KLM02Xh4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': '🎉🎉🎉🎉',
#   'Comment_Author': '@magaayya2726',
#   'Comment_Published': '2024-10-18T10:19:14Z'},
#  {'Comment_Id': 'UgwJr6Dxn_VzDR5ufGV4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Vaalthukal sam sir',
#   'Comment_Author': '@clayfinger7251',
#   'Comment_Published': '2024-10-17T11:25:49Z'},
#  {'Comment_Id': 'UgzKNizzt50oSkzz1bl4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Super sir',
#   'Comment_Author': '@SivaganeshD-x8j',
#   'Comment_Published': '2024-10-16T16:51:06Z'},
#  {'Comment_Id': 'UgxiDgAMgUuL8i8moSR4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'good super',
#   'Comment_Author': '@E9INTEGRATEDSYSTEMS',
#   'Comment_Published': '2024-10-14T13:39:25Z'},
#  {'Comment_Id': 'UgxJwBavXV1QwQQ2KAx4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Sir special theory of relativity mathiri famous equations ah explain panni derive pannunga',
#   'Comment_Author': '@t.a.screations',
#   'Comment_Published': '2024-10-13T09:57:03Z'},
#  {'Comment_Id': 'UgwIriql6UJxDxh-vYh4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thanks',
#   'Comment_Author': '@சக்திவேல்ராஜ்',
#   'Comment_Published': '2024-10-13T03:25:03Z'},
#  {'Comment_Id': 'UgxbGylXeEFv90ylVoJ4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Underrated Channel 😢❤',
#   'Comment_Author': '@ECMPrakashraj',
#   'Comment_Published': '2024-10-13T03:23:14Z'},
#  {'Comment_Id': 'Ugx_pWznDeOHZUtViY14AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'I am a co_scientist in Srilanka Reaserch centre and ur video so simply and clearly <br>Thank you mr.sam😊',
#   'Comment_Author': '@akkineshakkinesh353',
#   'Comment_Published': '2024-10-12T06:53:28Z'},
#  {'Comment_Id': 'UgzJzy_HwrHpYCUWlf14AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Super thalaiva',
#   'Comment_Author': '@s.g.karthikeyan4315',
#   'Comment_Published': '2024-10-12T00:57:33Z'},
#  {'Comment_Id': 'UgzFtJQWliE2hPtG6od4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Super bro',
#   'Comment_Author': '@hiiamyourfriend6780',
#   'Comment_Published': '2024-10-11T16:19:44Z'},
#  {'Comment_Id': 'UgxUqcEXWZHV_ENJjDJ4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'How neuro network works like memory',
#   'Comment_Author': '@jagans4896',
#   'Comment_Published': '2024-10-11T15:23:32Z'},
#  {'Comment_Id': 'UgxxLagIsQx_9LUYPkR4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thank you.',
#   'Comment_Author': '@babupriya8814',
#   'Comment_Published': '2024-10-11T14:54:50Z'},
#  {'Comment_Id': 'UgztzwCcM5ej1396W-J4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Mr. Gk  சேனலில் விளக்கியுள்ளார்',
#   'Comment_Author': '@freeenergy1778',
#   'Comment_Published': '2024-10-11T12:16:40Z'},
#  {'Comment_Id': 'UgxAh_cmlJTQNkpPWEF4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': '❤❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@VijayDhasu',
#   'Comment_Published': '2024-10-11T07:51:53Z'},
#  {'Comment_Id': 'UgyfWPKsuON7K0pHnKx4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': '<a href="UCkszU2WH9gy1mb0dV-11UJg/JAJ1XpGpJYnW8wTupZu4Cw"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/JAJ1XpGpJYnW8wTupZu4Cw"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/JAJ1XpGpJYnW8wTupZu4Cw"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/finger-red-number-one"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/finger-red-number-one"></a> nice explanation',
#   'Comment_Author': '@sahayam80',
#   'Comment_Published': '2024-10-11T07:42:33Z'},
#  {'Comment_Id': 'UgybWk0GUNmjMdubPbh4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Pangali neraya video podunga namma makkalukku scicence innum neraya theriyanum.',
#   'Comment_Author': '@manivannana3317',
#   'Comment_Published': '2024-10-11T07:32:35Z'},
#  {'Comment_Id': 'UgymQMwdJgvNO0G-TIt4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'இதில் கணிதம் மற்றும் கணிதப்புள்ளியியலின் (mathematical statistics) ன் பங்குதான் அதிகம்.',
#   'Comment_Author': '@ts.nathan7786',
#   'Comment_Published': '2024-10-11T05:37:14Z'},
#  {'Comment_Id': 'UgwhUjODgR4Tb6Y569Z4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Zef',
#   'Comment_Author': '@Sebastianthaninayaham',
#   'Comment_Published': '2024-10-10T22:52:00Z'},
#  {'Comment_Id': 'UgxMke2gF-uAKZugrqB4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': '💚🙏',
#   'Comment_Author': '@ஈழமாறன்',
#   'Comment_Published': '2024-10-10T17:23:14Z'},
#  {'Comment_Id': 'UgyJyO8rlStIx8EO-pt4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Well explained bro.',
#   'Comment_Author': '@jackreacher7183',
#   'Comment_Published': '2024-10-10T10:00:08Z'},
#  {'Comment_Id': 'UgyiOMFD_n00Vwa013Z4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'அற்புதமான விளக்கம். இன்னும் எளிமை படுத்துங்கள்... இதில் இயற்பியலும் கணிதமும் உள்ளது.',
#   'Comment_Author': '@vasanthakumark2372',
#   'Comment_Published': '2024-10-10T07:23:59Z'},
#  {'Comment_Id': 'UgyiTRRQXBe4mNltV1d4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Beautiful explanation 🎉🎉🎉🎉',
#   'Comment_Author': '@lms2638',
#   'Comment_Published': '2024-10-10T06:57:21Z'},
#  {'Comment_Id': 'UgxnjqJ0w8xIDlvTyZB4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': '👌🤝',
#   'Comment_Author': '@saravanank3204',
#   'Comment_Published': '2024-10-10T06:02:42Z'},
#  {'Comment_Id': 'UgwVqat3BSP6N5yF_jl4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Anna eanga poninga ievalo naal ah?',
#   'Comment_Author': '@aravindh850',
#   'Comment_Published': '2024-10-10T04:32:36Z'},
#  {'Comment_Id': 'UgwTuNEgrv_7ImglsM94AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'விளக்கம் அருமை!!!',
#   'Comment_Author': '@gopalsamykannan2964',
#   'Comment_Published': '2024-10-10T03:03:19Z'},
#  {'Comment_Id': 'Ugzl-oZWBj4qBKXHT6B4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Good Explanation, Thank you',
#   'Comment_Author': '@mohamedthaiebu4101',
#   'Comment_Published': '2024-10-10T03:01:46Z'},
#  {'Comment_Id': 'UgzMH12lHGA4J5GkD7N4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'நேர்த்தி',
#   'Comment_Author': '@chidambarams237',
#   'Comment_Published': '2024-10-10T02:03:03Z'},
#  {'Comment_Id': 'Ugx6bBL9obBwC8Nf4EV4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Ss squad ✨',
#   'Comment_Author': '@LEELEONARDO',
#   'Comment_Published': '2024-10-09T19:26:59Z'},
#  {'Comment_Id': 'UgzUyBP2WRtUkQBaa8F4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': '❤\u200d🔥🔥🔥🔥❤\u200d🔥❤\u200d🔥',
#   'Comment_Author': '@drtkings9119',
#   'Comment_Published': '2024-10-09T17:02:37Z'},
#  {'Comment_Id': 'UgzAaI1p8cEkKr5RUmZ4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'இன்ஜினியரிங்க்கு இயற்பியல் தாய் என்றால் கணிதம் தந்தை போன்றது.',
#   'Comment_Author': '@VinayagamoorthySivaperuman',
#   'Comment_Published': '2024-10-09T14:56:52Z'},
#  {'Comment_Id': 'UgzxsPOLUbnW5AGVi0N4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thank you sir ❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-10-09T14:36:58Z'},
#  {'Comment_Id': 'Ugy0p4MTlwaSrkFt1CF4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': '🎉🎉🎉🎉🎉🎉',
#   'Comment_Author': '@user-rq4dc2qw1t',
#   'Comment_Published': '2024-10-09T14:26:08Z'},
#  {'Comment_Id': 'UgyDJKZTfBaqjKc0rUJ4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Nice intro',
#   'Comment_Author': '@sampathjothi6198',
#   'Comment_Published': '2024-10-09T14:02:16Z'},
#  {'Comment_Id': 'UgwqVeTGCUfSt_fwB7N4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'தப்பா நினைக்காதிங்க சார் அறிவியலை உங்களமாதிரி எளிதில் மற்றவர்களாலால் முடியல சார் அதனால தினமும்  2 நிமிசமாவது வாங்க சார்',
#   'Comment_Author': '@ramalingamk826',
#   'Comment_Published': '2024-10-09T13:40:06Z'},
#  {'Comment_Id': 'UgwDp4qs-EBsWKOiy614AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'வாழ்த்துகள்🎉',
#   'Comment_Author': '@sampathjothi6198',
#   'Comment_Published': '2024-10-09T13:05:18Z'},
#  {'Comment_Id': 'UgxCfToPlsHR4l2tdXJ4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Super sir',
#   'Comment_Author': '@glazeinfotech1555',
#   'Comment_Published': '2024-10-09T12:07:40Z'},
#  {'Comment_Id': 'UgxHS2_k6F4DM3pNCuN4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Jesus bless your family Sir 🎉🎉🎉',
#   'Comment_Author': '@Saravanan-xz1dv',
#   'Comment_Published': '2024-10-09T11:57:43Z'},
#  {'Comment_Id': 'Ugwnzf0T3msiczv4Dex4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'How i read the famous scientists orginal research papers. Pls explain me.',
#   'Comment_Author': '@HiiiByiii',
#   'Comment_Published': '2024-10-09T11:57:09Z'},
#  {'Comment_Id': 'Ugxry6inCgxt7xDyKt54AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Nice explanation, keep it up 👍',
#   'Comment_Author': '@anandasekarankrishnamoorth3838',
#   'Comment_Published': '2024-10-09T11:47:15Z'},
#  {'Comment_Id': 'UgwXRt11qnbAXyqwTNJ4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thank you sir ❤',
#   'Comment_Author': '@gaakash5805',
#   'Comment_Published': '2024-10-09T11:35:53Z'},
#  {'Comment_Id': 'UgxEOJwXOaxWWWTver14AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thank you...❤',
#   'Comment_Author': '@rajendranr3856',
#   'Comment_Published': '2024-10-09T11:30:00Z'},
#  {'Comment_Id': 'UgwCaKhqcISol8JAmoF4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thank u Sir',
#   'Comment_Author': '@padhoo1973',
#   'Comment_Published': '2024-10-09T11:22:10Z'},
#  {'Comment_Id': 'Ugxqu02TppWxm3-Kcox4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Simple and well explanation brother!👍',
#   'Comment_Author': '@isvaryganesh5564',
#   'Comment_Published': '2024-10-09T10:30:41Z'},
#  {'Comment_Id': 'Ugy2vq4-fryfT077ikR4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thank you sir',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2024-10-09T10:29:24Z'},
#  {'Comment_Id': 'Ugwf7DFCHWw4ddixWFN4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Thank  you very much for ur video brother🎉🎉 very useful 👏👏',
#   'Comment_Author': '@believer-learner',
#   'Comment_Published': '2024-10-09T10:26:26Z'},
#  {'Comment_Id': 'UgxswV9dSqE1Q8IioyB4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Excellent Sam bro',
#   'Comment_Author': '@Charlesmanoharan',
#   'Comment_Published': '2024-10-09T10:11:33Z'},
#  {'Comment_Id': 'UgzKN2czkkWnUQilppN4AaABAg',
#   'Video_Id': 'YAfkc0ksRdw',
#   'Comment_Text': 'Is that yukawa&#39;s theory valid now? What is your openion.',
#   'Comment_Author': '@surendranmk5306',
#   'Comment_Published': '2024-10-09T10:11:07Z'},
#  {'Comment_Id': 'UgyzLFjIRzmK0ei5HZ94AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'my hand writing book post kpr college pysics department please rivue that !',
#   'Comment_Author': '@SURESHS-q2m',
#   'Comment_Published': '2024-11-13T06:54:50Z'},
#  {'Comment_Id': 'Ugyaai6Cold6zfY3gOJ4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'சூடான செய்தி சிறப்பு சார்.',
#   'Comment_Author': '@nagarajr7809',
#   'Comment_Published': '2024-10-09T04:27:36Z'},
#  {'Comment_Id': 'UgwmNuytnQRcxPc-Esh4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'Thank you sir',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-10-09T03:32:58Z'},
#  {'Comment_Id': 'UgyltVwUKzP5n30VH3J4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'Sir automatic watch and normal watch, idhula irukkura science pathi vedio podungka sir',
#   'Comment_Author': '@drtkings9119',
#   'Comment_Published': '2024-10-09T02:28:53Z'},
#  {'Comment_Id': 'Ugy3G7z360riagcn-ol4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'நேயர் விருப்பம் : மிகவும் தகுதி உள்ளவர்களுக்குதான் விருது கிடைத்துள்ளது. ஆனால் இது இயற்பியல் துறைக்கு தரப்பட்டிருக்கலாமா ? உங்கள் கருத்துக்களை தெரிந்து கொள்ள விரும்புகிறேன்.',
#   'Comment_Author': '@MrDharma111',
#   'Comment_Published': '2024-10-09T02:10:19Z'},
#  {'Comment_Id': 'UgzzPqHtrOhVfZ--Opd4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'செயற்கை நுண்ணறிவு <br>நன்மைகளுக்கு மட்டுமே பயன்பட வேண்டும்...❤',
#   'Comment_Author': '@saravanank3204',
#   'Comment_Published': '2024-10-08T19:30:01Z'},
#  {'Comment_Id': 'UgwvOEGneL14QU2FGr14AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'super sir.🎉🎉',
#   'Comment_Author': '@karthickeyan6603',
#   'Comment_Published': '2024-10-08T18:38:56Z'},
#  {'Comment_Id': 'UgwE4_8UMSPMNgGqhZN4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'Where do i study famous scientists original research papers to improve my knowledge. Pls tell me. I ve no idea.',
#   'Comment_Author': '@HiiiByiii',
#   'Comment_Published': '2024-10-08T15:00:59Z'},
#  {'Comment_Id': 'UgxsB-sGYP7UwuDRo3F4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'looks like they have given it to improve the Data Science field...',
#   'Comment_Author': '@kircyclone',
#   'Comment_Published': '2024-10-08T13:52:52Z'},
#  {'Comment_Id': 'UgzyyWccmQTIv585Oe54AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'bro intha mari physics journal paper review  podunga sir',
#   'Comment_Author': '@hariharann2668',
#   'Comment_Published': '2024-10-08T12:44:19Z'},
#  {'Comment_Id': 'UgzG8qcEL3BgxW_xCYd4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'Dirac equation பற்றி ஒரு வீடியோ போடுங்க அண்ணா',
#   'Comment_Author': '@VinayagamoorthySivaperuman',
#   'Comment_Published': '2024-10-08T11:50:09Z'},
#  {'Comment_Id': 'UgyJrydr8NFS-rtuge54AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'Bro analum ithu physics ila 😢',
#   'Comment_Author': '@abdulrehaman4548',
#   'Comment_Published': '2024-10-08T11:17:39Z'},
#  {'Comment_Id': 'UgymgJukSCL4aJ9o5414AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': '🎉 congratulations to 40 years of conscious work',
#   'Comment_Author': '@indumathik6108',
#   'Comment_Published': '2024-10-08T10:58:29Z'},
#  {'Comment_Id': 'Ugx0U6AnUf7axulpxIJ4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'You are a gift for tamil world from nature. I&#39;m allways proud of you.',
#   'Comment_Author': '@surendranmk5306',
#   'Comment_Published': '2024-10-08T10:56:22Z'},
#  {'Comment_Id': 'UgxjAZtSsdc2gcInBQJ4AaABAg',
#   'Video_Id': '_a1-QpK3aqQ',
#   'Comment_Text': 'வாழ்த்துக்கள்',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2024-10-08T10:22:21Z'},
#  {'Comment_Id': 'UgziKFE7wdFNOLBhBtl4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Please keep posting videos to create awareness.',
#   'Comment_Author': '@thiyagamurthipoorasamy4542',
#   'Comment_Published': '2024-10-11T06:18:09Z'},
#  {'Comment_Id': 'Ugy9N-WmdzqlBLRJ_ep4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Welcome thalaiva',
#   'Comment_Author': '@s.g.karthikeyan4315',
#   'Comment_Published': '2024-10-08T06:23:07Z'},
#  {'Comment_Id': 'UgwRVGdnY-j5jTjZHet4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Sir talk about Wolfgang Pauli',
#   'Comment_Author': '@dharanidharan.16',
#   'Comment_Published': '2024-10-07T20:09:32Z'},
#  {'Comment_Id': 'UgzkeFdhS_mW6hUv77l4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Subscriber think : Sam Enna kaaram soldrarunu kepom<br><br>Sir : Karanam venam vedio kulla poovom... 😂<br><br>Subscriber :😳😒😂',
#   'Comment_Author': '@mohammedyasin3431',
#   'Comment_Published': '2024-10-06T17:51:05Z'},
#  {'Comment_Id': 'UgxII1PIjOkFopoJQ2t4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Sir intha inthe theory,maths pathiyum yelimeya video podungq👍',
#   'Comment_Author': '@zeerah995',
#   'Comment_Published': '2024-10-06T17:25:45Z'},
#  {'Comment_Id': 'UgzzfEe_VHJ1t3H42f94AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'I always check your chenel...<br><br>Neenga deppane scincum, scintist historiyum,new invention pathi pesurathu nicheyema orunal hit aahum...keep continue',
#   'Comment_Author': '@zeerah995',
#   'Comment_Published': '2024-10-06T17:14:31Z'},
#  {'Comment_Id': 'UgyZDepEHNPGDBoLu6x4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Welcome back sam brother 😊. Keep teaching us.',
#   'Comment_Author': '@darrelllyjo9162',
#   'Comment_Published': '2024-10-06T16:23:23Z'},
#  {'Comment_Id': 'UgyhrU5PepxEZtSwONJ4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'வணக்கம் சார் 🎉',
#   'Comment_Author': '@svenkataramanan5393',
#   'Comment_Published': '2024-10-05T13:02:49Z'},
#  {'Comment_Id': 'UgxZ3iblbnmf-dohlMZ4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Kb.',
#   'Comment_Author': '@ckanakarajan',
#   'Comment_Published': '2024-10-04T17:07:48Z'},
#  {'Comment_Id': 'UgyUXB-pk-IdavrSKoh4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Sir can you please make more videos on quantum mechanics',
#   'Comment_Author': '@PickCloud',
#   'Comment_Published': '2024-10-04T17:01:39Z'},
#  {'Comment_Id': 'Ugx_ARzI6FC0G27B6Bl4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Happy to see u after long break sir..Thank you',
#   'Comment_Author': '@jacqulin5731',
#   'Comment_Published': '2024-10-04T15:43:13Z'},
#  {'Comment_Id': 'Ugw5sAXP7hX_gGuUJCd4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'உங்க இஷ்டத்துக்கும்  போரீங்க உங்க இஷ்டத்துக்கும் வரீங்க.நாங்க எவ்வளவு பாதிக்கப்பட்டோம் என்று தெரியுமா?',
#   'Comment_Author': '@ParthiPan-gh5zr',
#   'Comment_Published': '2024-10-04T15:06:02Z'},
#  {'Comment_Id': 'UgzjzHt5KPDcMj8fCC54AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'please periodically sir(at least weekly) <br>if you can🎉🎉🎉',
#   'Comment_Author': '@channel12381',
#   'Comment_Published': '2024-10-04T14:29:12Z'},
#  {'Comment_Id': 'Ugw1HKTcgPhqJ4tlcjd4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'என்ன சாம்,  ரொம்ப இடைவெளி எடுத்துகிட்டீங்க....? <br>எப்படி இருக்கீங்க..! நாம்தானே!?!',
#   'Comment_Author': '@sundharesanps9752',
#   'Comment_Published': '2024-10-04T14:08:34Z'},
#  {'Comment_Id': 'UgzfvHgoj5r-HvUapZt4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Waiting to see you, sir.',
#   'Comment_Author': '@yashwant12-b50',
#   'Comment_Published': '2024-10-04T11:57:12Z'},
#  {'Comment_Id': 'UgyniTUKCJprA7N_57Z4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Happy to hear you brother!👍👍👍',
#   'Comment_Author': '@isvaryganesh5564',
#   'Comment_Published': '2024-10-04T11:37:52Z'},
#  {'Comment_Id': 'UgxDUC0XRG8sj-nKUJ94AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Isreal sir unga sira',
#   'Comment_Author': '@Captain-veg',
#   'Comment_Published': '2024-10-04T11:22:12Z'},
#  {'Comment_Id': 'UgyUaQUTjE4TULXEPgZ4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Science with Sam come back ❤',
#   'Comment_Author': '@dhanasekaran2491',
#   'Comment_Published': '2024-10-04T07:28:18Z'},
#  {'Comment_Id': 'UgwEvthftuKrFWOpAZx4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'ஐயா❤<br>எங்களை விட்டு ஓடிடாதேயும்',
#   'Comment_Author': '@zailanumu7596',
#   'Comment_Published': '2024-10-04T06:24:21Z'},
#  {'Comment_Id': 'UgxwNytf8x8oHCBvkOJ4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Come back 🔥',
#   'Comment_Author': '@pradeep517',
#   'Comment_Published': '2024-10-04T05:56:19Z'},
#  {'Comment_Id': 'UgxdflwyUuIZUbl5brN4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Thank you..🎉',
#   'Comment_Author': '@rajendranr3856',
#   'Comment_Published': '2024-10-04T05:37:49Z'},
#  {'Comment_Id': 'Ugy_0ot8JJK5Mfqr0Fh4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Nalla irukingala sir?',
#   'Comment_Author': '@vikramathithan_nj1074',
#   'Comment_Published': '2024-10-04T03:30:47Z'},
#  {'Comment_Id': 'UgxK_ndBbV3nEpbGjf54AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Sam is back back back ...',
#   'Comment_Author': '@akkineshakkinesh353',
#   'Comment_Published': '2024-10-04T03:14:26Z'},
#  {'Comment_Id': 'UgzjoCDPO53-xvoC7hx4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Hai sir can I have your gmail',
#   'Comment_Author': '@jeganram2688',
#   'Comment_Published': '2024-10-04T02:33:00Z'},
#  {'Comment_Id': 'Ugy-Dj8r0-hhkIoVMJV4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Please put enough videos in YouTube sir🙏🙏',
#   'Comment_Author': '@kumarankumaran3947',
#   'Comment_Published': '2024-10-04T01:55:12Z'},
#  {'Comment_Id': 'Ugwt6qc_39n8--HQW6t4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Sir come back ❤❤❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-10-04T01:35:33Z'},
#  {'Comment_Id': 'UgzGwT4Gpbw-yG10_Kt4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Welcome🎉',
#   'Comment_Author': '@manivannan.s4158',
#   'Comment_Published': '2024-10-04T01:16:33Z'},
#  {'Comment_Id': 'UgwuiDRffX-NDiAZ5wB4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Welcome',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2024-10-04T00:21:15Z'},
#  {'Comment_Id': 'UgzVtngrJWxa-WEMPSt4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Sir வந்து  பேசுங்கள்  sir நாங்க தெளிவு  பெற வந்து  பேசுங்கள்  sir (இது  அறிவை  தேடும்  கிராமத்தானின் வேண்டுகோள்)',
#   'Comment_Author': '@ramalingamk826',
#   'Comment_Published': '2024-10-03T21:19:17Z'},
#  {'Comment_Id': 'UgwycpOSPwCP9x0YJbl4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'jj thomson video poduga, sir.',
#   'Comment_Author': '@karthickeyan6603',
#   'Comment_Published': '2024-10-03T20:29:53Z'},
#  {'Comment_Id': 'UgyPCtoS8l3EEmSlQEd4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': '❤👌',
#   'Comment_Author': '@saravanank3204',
#   'Comment_Published': '2024-10-03T19:50:34Z'},
#  {'Comment_Id': 'Ugw-sKrmA1FctJ10mWF4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Finally sir back to form❤😅',
#   'Comment_Author': '@baraniphysics',
#   'Comment_Published': '2024-10-03T18:09:13Z'},
#  {'Comment_Id': 'UgwMsFl4l_bkNjXJIUV4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Welcome bro',
#   'Comment_Author': '@Russiaboolik',
#   'Comment_Published': '2024-10-03T18:06:54Z'},
#  {'Comment_Id': 'UgwQrMD6Jh0fh_QKSXF4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Finally, you remembered the password for your YouTube channel😂😂',
#   'Comment_Author': '@santho6972',
#   'Comment_Published': '2024-10-03T17:35:05Z'},
#  {'Comment_Id': 'Ugxe2XGU15qvi0t1Est4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Interesting sir! Good summary 👍. Looking forward more like this',
#   'Comment_Author': '@indumathik6108',
#   'Comment_Published': '2024-10-03T17:07:04Z'},
#  {'Comment_Id': 'Ugz3Xie5B_VhojCWEZR4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Welcome back bro...',
#   'Comment_Author': '@sampathjothi6198',
#   'Comment_Published': '2024-10-03T17:03:15Z'},
#  {'Comment_Id': 'Ugwtq41J_4tIMJfEmst4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Happy to see you sir❤',
#   'Comment_Author': '@user-rq4dc2qw1t',
#   'Comment_Published': '2024-10-03T17:03:12Z'},
#  {'Comment_Id': 'UgyivtNpscoTc6R9Vct4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Science With Sam Return 🔥🔥🔥',
#   'Comment_Author': '@prabanjan.pkavaskar.p7449',
#   'Comment_Published': '2024-10-03T17:02:16Z'},
#  {'Comment_Id': 'Ugyyfuaebkv28GFu8Gt4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Pls explain more',
#   'Comment_Author': '@MrJhonsamuel',
#   'Comment_Published': '2024-10-03T16:55:45Z'},
#  {'Comment_Id': 'UgwwECPHxdY5-NqoBqZ4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Happy to see you again Sir, Please regular ah video podunga Sir Pls',
#   'Comment_Author': '@karand6241',
#   'Comment_Published': '2024-10-03T16:39:19Z'},
#  {'Comment_Id': 'Ugy2ulvg7thcp7Hc_ON4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Sir How are you Sir???',
#   'Comment_Author': '@karand6241',
#   'Comment_Published': '2024-10-03T16:38:45Z'},
#  {'Comment_Id': 'Ugx0Y9nBwJBBU6Pjflt4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': 'Welcome back ❤',
#   'Comment_Author': '@hariharanbarade6229',
#   'Comment_Published': '2024-10-03T16:38:32Z'},
#  {'Comment_Id': 'UgzEVCh4jqboybLA4Hx4AaABAg',
#   'Video_Id': 'TbISw1Yt_1U',
#   'Comment_Text': '🎉',
#   'Comment_Author': '@jailani3585',
#   'Comment_Published': '2024-10-03T16:38:30Z'},
#  {'Comment_Id': 'Ugx3qziodUnnS82ViCN4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'இன்னும் ஒரு வாரத்தில் நோபல் பரிசு அறிவிப்பு வெளியாகும் உங்களுடைய விவரித்தலுக்கு காத்து இருக்கிறேன்.',
#   'Comment_Author': '@VinayagamoorthySivaperuman',
#   'Comment_Published': '2024-09-30T02:53:51Z'},
#  {'Comment_Id': 'UgwrStH-2s0u_wv07OF4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Hi Sam, E=Hv is Plank Equation i guess, pardon me if I am wrong',
#   'Comment_Author': '@venkatesanrengasamy1184',
#   'Comment_Published': '2024-09-23T15:19:06Z'},
#  {'Comment_Id': 'UgwnVsbA_DBRaJ3ROYx4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Bro, how to understand math',
#   'Comment_Author': '@ganesh193',
#   'Comment_Published': '2024-09-15T16:19:13Z'},
#  {'Comment_Id': 'UgwYRglTPEXcpHTv9Ux4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir quartz, automatic and atomic watch idhula irukkura science pathi video podungka please...',
#   'Comment_Author': '@drtkings9119',
#   'Comment_Published': '2024-09-14T01:51:10Z'},
#  {'Comment_Id': 'UgzI9nb2kYDnBQrCnw54AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'sir where is next video ,I&#39;m waiting for the video sir',
#   'Comment_Author': '@Ayush44437',
#   'Comment_Published': '2024-09-12T09:37:15Z'},
#  {'Comment_Id': 'UgyIfRWE9oeDwrcUbiN4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir, Why elements colour different in each.',
#   'Comment_Author': '@akashpalani9398',
#   'Comment_Published': '2024-09-04T13:10:58Z'},
#  {'Comment_Id': 'Ugys8wolvNqibVnr1H14AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir Naan nobel prize physicsla vangalamnu iruken sir unga phone number kudunga sir &amp; unga chanel very useful thank younka sir',
#   'Comment_Author': '@prakashperiyasamy2500',
#   'Comment_Published': '2024-09-04T03:12:18Z'},
#  {'Comment_Id': 'Ugx_ss-KnVjEb6Ioilx4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Bro do you believe God...?',
#   'Comment_Author': '@KARTHIK-mv3rq',
#   'Comment_Published': '2024-09-03T22:12:13Z'},
#  {'Comment_Id': 'UgxIW6BqGrdQ161LC4N4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'excellent. i need 5 hours  documentaries on space topics and quantum mechanics.. 😮😊',
#   'Comment_Author': '@ilavarasiramalingam268',
#   'Comment_Published': '2024-08-25T22:56:39Z'},
#  {'Comment_Id': 'UgzrxhrewkCOlMZ6dnp4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir, from recently I&#39;m watching your videos.. It&#39;s really super please don&#39;t stop uploading I&#39;m watching every night 🙏🏻🙏🏻🙏🏻',
#   'Comment_Author': '@mohankeerthi.m.m7129',
#   'Comment_Published': '2024-08-23T20:00:29Z'},
#  {'Comment_Id': 'UgxsgCjlGo9Ygga2HFJ4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Hi bro,<br><br><a href="https://www.youtube.com/watch?v=K823D9Y0cE0">https://www.youtube.com/watch?v=K823D9Y0cE0\r</a><br>\r<br>Maybe I was wrong, but according to this video content, they mention that using this shortest light pulse, we can capture the electron&#39;s position and momentum. But you already told me it&#39;s not possible to find the electron&#39;s movement and position at the same time, correct bro?\r<br>\r<br>Can you please explain this and what advantages there are to using this?',
#   'Comment_Author': '@techh4ck936',
#   'Comment_Published': '2024-08-10T14:11:52Z'},
#  {'Comment_Id': 'UgxPYLD_Hd892kWPz-F4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir not sure you would be able to read my comments due to your busy work times.. my request is if added a real time small science experiment in videos along with the theorical may bring more attention to video and understanding of concents.',
#   'Comment_Author': '@muruganmuru593',
#   'Comment_Published': '2024-08-08T17:46:29Z'},
#  {'Comment_Id': 'UgxKFBlelBEP28r2yP54AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir can you please make video such as&quot; how to study abroad and qualifications required for ug,pg and more...YOU ARE A RIGHT PERSON TO DO SIR!!!',
#   'Comment_Author': '@Suraj-xz8gi',
#   'Comment_Published': '2024-08-08T11:17:47Z'},
#  {'Comment_Id': 'UgwCV_DLHYLt12n2hv94AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': '’Double slit experiment in time’ explain pannunga bro',
#   'Comment_Author': '@vigneshvivek2719',
#   'Comment_Published': '2024-07-30T19:40:47Z'},
#  {'Comment_Id': 'Ugyn8C8JviA1-tKNr0J4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir is there any reason for why the electron spin creates magnetic field perpendicular to the spin? Sir If in any one of the  video if you already said about this please mention sir ?',
#   'Comment_Author': '@Karthikeyan.SIX-B',
#   'Comment_Published': '2024-07-28T10:50:53Z'},
#  {'Comment_Id': 'Ugzrrx2tfm5gs7jmz9F4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Jesus with us 🙏 ❤️ 🙌 <br>Samuel sir',
#   'Comment_Author': '@Saravanan-xz1dv',
#   'Comment_Published': '2024-07-28T05:37:54Z'},
#  {'Comment_Id': 'UgxUNEOdN0VmJaYpTkJ4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Thalaivaa sunitha villiam ku enna Achiii',
#   'Comment_Author': '@leeleonardo6152',
#   'Comment_Published': '2024-07-25T02:15:41Z'},
#  {'Comment_Id': 'UgzBxUmZ08EclAn9YMZ4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir wave pocket ah pathi explain panni oru video post pannunga',
#   'Comment_Author': '@ajayr9751',
#   'Comment_Published': '2024-07-17T04:30:08Z'},
#  {'Comment_Id': 'UgzMwCLZpiAW2sTZ9L54AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Sir next video',
#   'Comment_Author': '@VinayagamoorthySivaperuman',
#   'Comment_Published': '2024-07-15T23:56:17Z'},
#  {'Comment_Id': 'Ugw8I5vqiaQPUsFgcrh4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'உங்கள் சேனலுக்கான அங்கீகாரம் விரைவில் கிடைக்கும்.',
#   'Comment_Author': '@VinayagamoorthySivaperuman',
#   'Comment_Published': '2024-07-12T11:47:53Z'},
#  {'Comment_Id': 'Ugy8_gnlYFPZFL3HEBd4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'அண்ணா எப்போ அறிவியல் சம்பந்தமான வீடியோ போடுவிங்க 10 நாள் ஆகுது',
#   'Comment_Author': '@VinayagamoorthySivaperuman',
#   'Comment_Published': '2024-07-12T11:46:36Z'},
#  {'Comment_Id': 'UgzwMdNctFulCi4ZI2J4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Nice.  Thank you.  Double slit experiment with elecrons could have been included.    If necessary, increase the time upto 30 minutes or even slightly more.  S Chitrai Kani',
#   'Comment_Author': '@sckani3432',
#   'Comment_Published': '2024-07-12T03:59:15Z'},
#  {'Comment_Id': 'UgyUMXjnTaKbij02Kyx4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Super  boss',
#   'Comment_Author': '@Praba-o1s',
#   'Comment_Published': '2024-07-10T22:26:57Z'},
#  {'Comment_Id': 'Ugz_pDVlHjs87mWxknB4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'நீயே ஒளியானால் எதைக்காண்பாய்?',
#   'Comment_Author': '@MM-dh3wr',
#   'Comment_Published': '2024-07-08T22:42:04Z'},
#  {'Comment_Id': 'UgzS6_pLZPeHl6MnEdp4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Simulation theory video upload sir🥺',
#   'Comment_Author': '@RAMUK_HTARAS',
#   'Comment_Published': '2024-07-08T03:56:51Z'},
#  {'Comment_Id': 'Ugx4RBKuPdZFKLa2iKx4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'வணக்கம் தம்பி, கருந்துளை பற்றி ஏதாவது பதிவு தமிழில் இருந்தால் அதன் link கொடுங்க நன்றி.',
#   'Comment_Author': '@ravisundaram1648',
#   'Comment_Published': '2024-07-06T10:36:00Z'},
#  {'Comment_Id': 'UgxMPSJ2xyOAqGhio3x4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'mass na nirai thana...',
#   'Comment_Author': '@praveenm8460',
#   'Comment_Published': '2024-07-05T05:28:34Z'},
#  {'Comment_Id': 'UgwTrAeLzfeZ1Arn36V4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Thank you sir. I just read this yesterday in my school library it&#39;s amazing ❤',
#   'Comment_Author': '@faakmal6685',
#   'Comment_Published': '2024-07-05T00:57:47Z'},
#  {'Comment_Id': 'Ugy0T6L8vcW2GnKwcqd4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'அண்ணா இப்போது உள்ள தொழில்நுட்பத்தை வைத்து நம்மால் எவ்வளவு anti matter ஐ உருவாக்க முடியும்.anti matter bomb வெடித்தால் என்ன விளைவுகள் ஏற்படும் anti matter   இன்ஜின் உருவாக்க வாய்ப்பு உள்ளதா.நம்மால் பால்வெளி மண்டலம் விட்டு வெளியில் செல்ல முடியுமா',
#   'Comment_Author': '@VinayagamoorthySivaperuman',
#   'Comment_Published': '2024-07-03T11:47:54Z'},
#  {'Comment_Id': 'Ugxuo5ou8RfHTRVJM6p4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Thankyou professor',
#   'Comment_Author': '@joyenjoy7333',
#   'Comment_Published': '2024-07-02T12:37:33Z'},
#  {'Comment_Id': 'UgzwGzTtF644U0faUdl4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'தம்பி, எந்த கேள்வி கேட்டாலும், காற்றோடு போனது போல் நீ கண்டு கொள்ளாது போவது, உமது காணொளியை காணும் ஆர்வத்தை குறைக்கிறது. இருந்தாலும் கேட்கிறேன்.<br>E=MC^2<br>Energy=Mass x light velocity square<br>எல்லாவற்றுக்கும் ஒரு அலகு (Unit) உண்டு. அப்படி E க்கு அதன் formula   படி E=MC^2<br>Mass in gram<br>Speed of light=km/sec<br>E=gram * (km/sec)^2 <br>E=g*km^2/sec^2 என்ற unit ல் Energy ஐ குறிப்பதாக தெரியவில்லை.<br>In fact, Energy is common name. So many energies are there. Like heat energy, light energy, sound energy, potential energy, kinetic energy etc. Depending upon the kind of energy the unit will differ. <br>உங்கள் முன் நான் ஒரு முட்டாளாக கூட இருக்கலாம். ஆனால், என் மனதில் இப்படி எல்லாம் வினா எழுகிறது. முடிந்தால் விளக்குக.',
#   'Comment_Author': '@vsparthiban2679',
#   'Comment_Published': '2024-07-02T11:41:11Z'},
#  {'Comment_Id': 'UgyEpkuYKi36gplNj6J4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Hai Sam sir may i know your _ Phy _  or <i>_PGP_</i> ?????',
#   'Comment_Author': '@vigneshwaran1865',
#   'Comment_Published': '2024-07-02T09:19:01Z'},
#  {'Comment_Id': 'Ugzr5mpra9JhdKEQjCh4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'To move a particle, it needs a force, even though it&#39;s tiny, but light doesn&#39;t require any force to move because a light wave is constantly going forward by itself from where it formed. Light may have only a wave nature.',
#   'Comment_Author': '@selvakumar-nr4ir',
#   'Comment_Published': '2024-07-02T06:46:28Z'},
#  {'Comment_Id': 'Ugye-2RDiTkFCcr6PAd4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Ss army 🪖',
#   'Comment_Author': '@RAMUK_HTARAS',
#   'Comment_Published': '2024-07-02T03:16:11Z'},
#  {'Comment_Id': 'Ugy06YnLNZe6X2MMRfh4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'தமிழர்கள் ஒரிசாவை ஆள்வதா? என்ற இனவெறி பிரச்சாரம் மூலம் நவீன் பட்நாயக்கை தோற்கடித்தார்கள். ஆனால் தமிழ்நாட்டை கண்டவெனெல்லாம் ஆளலாம்.',
#   'Comment_Author': '@kandasamys8994',
#   'Comment_Published': '2024-07-02T03:13:43Z'},
#  {'Comment_Id': 'UgyLD1TTsBDOmNT4p_94AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'Super❤.<br>Nuclear physics sub atomic particles video podunga sir.',
#   'Comment_Author': '@k.velmuruganscience1398',
#   'Comment_Published': '2024-07-02T03:00:51Z'},
#  {'Comment_Id': 'Ugw8cvgSHLg6qGnvtoR4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'இந்த பிரபஞ்சம் விரிவடைய காரணம் என்ன... !!??<br><br>ஏதோ ஒரு உந்து சக்தி நம்மை தொடந்து உந்தி விரிவடைய செய்கிறது.... <br><br>நமக்கும் துகள் / அலைபண்பு உள்ளது..... ( நிறை உள்ளவை எதுவாயினும் = [ எலக்ட்ரான் / மனிதர்கள் / பூமி / சூரிய குடும்பம் ] = ஒளித்துகள் ( photon&#39;s களும் இதையே ஒத்து உள்ளன... )🤔🤔🤔🤨🤨🤨<br><br><br>கவனிக்க வேண்டியது.... Photons கள் ஒளியின் வேகத்தில் நகர்கின்றன...  இந்த பிரபஞ்சத்தில்...🤔🤔 ஆனால் எடை அதிகம் உள்ள பொருட்கள்... ஒரு குறிப்பிட்ட வேகத்தில் நகர்கின்றன.....<br><br><br>இரண்டயுமே நகர்த்த ஏதோ ஒரு சக்தி தேவை....  நான் dark matter மற்றும் dark engery பற்றி பேச விரும்பவில்லை.... <br><br>CMB க்கும்.... 🤔🤨  இதற்கும் என்ன தொடர்பு....<br><br>நாம் கண்ணுக்கு புலப்படும் ஒளியை வைத்தே ( வெளிச்சம் மற்றும் இரவு ) என்று சொல்கிறோம்....<br><br><br>ஆனால் மின் காந்த அலைகளில் நம் கண்ணுக்கும் புலனாகத அலை நீளங்கள் உண்டு.   <br><br><br><b>Electrons and Photons</b><br><br>Photons and electrons are two of the basic quantum-mechanical particles but they have completely different properties. Photon is a type of elementary particle which acts as a carrier of energy, but the electron is a subatomic particle which occurs in all the atoms. In this article, we will learn about the definition, meaning and differences between electrons and photons.<br><br>Difference Between Photon and Electron<br><br>Photons and electrons are both fundamental particles, the former of\xa0electromagnetic waves\xa0and the latter of atoms. Together, they can cause the flow of electricity. However, they are different in many aspects:',
#   'Comment_Author': '@MakeshKumar007',
#   'Comment_Published': '2024-07-01T21:38:32Z'},
#  {'Comment_Id': 'UgwgmaUFXMMiCqHMUAJ4AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
#   'Comment_Text': 'எனக்கு எதுவும் புரியவில்லை... ஆனால் இதில் ஏதோ ஒன்று ஒளிந்து இருக்கிறது.... அதை என்னால் புரிந்து கொள்ள முடியவில்லை...🤔🤨😊🤗<br><br>When one of the bodies is much larger than the other, as is true for Earth and anything on its surface, its mass predominates. Every object on Earth&#39;s surface is attracted to the center of the planet with a force proportional to its mass, giving rise to the adage: &quot;whatever goes up must come down,&quot; which is true as long as the object isn&#39;t moving fast enough to leave the ground and go into orbit.<br><br>Other planets exert the same type of gravitational force on objects on their surface, but the magnitude of this force is different. It depends not only on the planet&#39;s mass, but also its density, because the denser a planet is, the more mass there is under your feet pulling you down.<br><br>The Gravity of Different Planets<br><br>On Earth, falling objects experience an acceleration of 9.8 m/s2\xa0due to Earth&#39;s gravitational force, and that is defined as 1 g. The easiest way to discuss the gravitational force on other planets is to express it as a fraction of Earth&#39;s g-force.<br><br>Jupiter is the largest planet, so you would expect it to have the largest gravitational force, and it does. The reasoning doesn&#39;t extend the other way, though. Mercury is the smallest planet, but its surface gravity is about the same as that of the much larger Mars because Mercury is more dense. Similarly, Saturn is much larger than Earth, but it&#39;s much less dense, so the gravitational force on Saturn is about the same as it is on Earth.<br><br>The gravity you would experience on each of the planets in the solar system if you were standing on the surface or, in the case of the ice giants, floating in the atmosphere, is:<br><br>Mercury: 0.38 g<br><br>Venus: 0.9 g<br><br>Moon: 0.17 g<br><br>Mars: 0.38 g<br><br>Jupiter: 2.53 g<br><br>Saturn: 1.07 g<br><br>Uranus: 0.89 g<br><br>Neptune: 1.14 g<br><br>The Gravitational Pull of the Planets<br><br>All the planets exert a gravitational pull on Earth, but except for the sun and moon, the magnitude of this pull is basically negligible. This is due to the vast distances between the Earth and the other planets. The gravitational force varies inversely with the square of the distance between bodies but directly only with the first power of mass, so distance is more important.<br><br>The moon is small, but it&#39;s the closest body to Earth, so its gravitation is strongest. If you express the tidal forces, of all other planets in terms of the moon&#39;s force, the results are as follows:<br><br>Moon: 1<br><br>Sun: 0.4<br><br>Venus: 6 × 10-5<br><br>Jupiter: 3 × 10-6<br><br>Mercury: 4 × 10-7<br><br>Saturn: 2 × 10-7<br><br>Mars: 5 × 10-8<br><br>Uranus: 3 × 10-9<br><br>Neptune: 8 × 10-10<br><br>Planetary Gravitational Influences Fluctuate<br><br>The planets aren&#39;t stationary. Their distance from Earth changes and so, accordingly, does their gravitational influence on our home planet. The magnitude of the force can vary by as much as an order of magnitude. This may be one reason why astrologers throughout the ages have found a correspondence between the positions of the planets and conditions on Earth.',
#   'Comment_Author': '@MakeshKumar007',
#   'Comment_Published': '2024-07-01T21:11:38Z'},
#  {'Comment_Id': 'UgxwSUUHMk9po2rZuR14AaABAg',
#   'Video_Id': 'irLLYHYLrQs',
# ...
#   'Comment_Author': '@emanacio',
#   'Comment_Published': '2023-10-02T17:24:31Z'},
#  {'Comment_Id': 'UgyF3vba48CClyrMC5N4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'Very Thanks for immediately vid❤',
#   'Comment_Author': '@AfsherRafeek',
#   'Comment_Published': '2023-10-02T16:27:05Z'},
#  {'Comment_Id': 'Ugw5aSU3ZOnr1oLAP3V4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'நம்பிக்கை இல்லை. இவர்களின் சோதனை எலிகள் நாம்',
#   'Comment_Author': '@sundaramss1545',
#   'Comment_Published': '2023-10-02T16:07:43Z'},
#  {'Comment_Id': 'UgxFMbJWZMIK2PfmKi94AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'நன்றி நன்றி ....சுடச்சுட',
#   'Comment_Author': '@abdulyouare100percentright9',
#   'Comment_Published': '2023-10-02T15:05:08Z'},
#  {'Comment_Id': 'UgzjSUFU8rGyKrMMsAp4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'உடனடியாக வீடியோ போட வேண்டும் என்பதை விட நீங்கள் எப்போதும் போல் relax ஆக பேசுகின்ற விதத்திலேயேயே வீடியோ போடுங்க . இருப்பினும் துரிதமான வீடியோவுக்கும் நன்றி .',
#   'Comment_Author': '@ramupattu9444',
#   'Comment_Published': '2023-10-02T14:51:21Z'},
#  {'Comment_Id': 'Ugwz1RhFl0P3MlHKkmN4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'Thanks sir ❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2023-10-02T12:35:28Z'},
#  {'Comment_Id': 'UgwVAXe8L0-5mzpMfc14AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'தகவலுக்கு மிக்க நன்றி🙏',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2023-10-02T12:23:18Z'},
#  {'Comment_Id': 'UgwT4afcTwq7IK86zal4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'உங்களுக்கு எப்படி மிக அற்புதமான தகவல்கள் உடனடியாக தெரிகிறது',
#   'Comment_Author': '@nmathiyalaganmarishwaran',
#   'Comment_Published': '2023-10-02T11:47:25Z'},
#  {'Comment_Id': 'UgxMDXEQYAYuQOyxVe94AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': '🎉🎉🎉',
#   'Comment_Author': '@muthukbrothers02',
#   'Comment_Published': '2023-10-02T11:42:48Z'},
#  {'Comment_Id': 'UgxePFGFUZ_w2IOe2ut4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'Conspiracy theorist pathi oru video poduga bro ...avuga covid vaccine and science related ah soldrathu unma mathiriya irukku .. for example <br>1 thangapandian sekar (face look like you)<br>2 Saravanan paramantham<br>3 real face<br>(You tube channel)',
#   'Comment_Author': '@asanmohamed3875',
#   'Comment_Published': '2023-10-02T10:34:34Z'},
#  {'Comment_Id': 'Ugy56gxNW_z0f6hkyE14AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': 'VIDEO    Poodu    Thaliva             VIDEO Poodu',
#   'Comment_Author': '@srikrithika2382',
#   'Comment_Published': '2023-10-02T10:20:39Z'},
#  {'Comment_Id': 'UgyRQ7RnpJwUg3XNakx4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': '🎉🎉❤',
#   'Comment_Author': '@VennilaS-ql4ow',
#   'Comment_Published': '2023-10-02T10:18:49Z'},
#  {'Comment_Id': 'UgxLyzS7SiWJdrXUrmN4AaABAg',
#   'Video_Id': 'IezbYe4KnAg',
#   'Comment_Text': '🎉',
#   'Comment_Author': '@savithachellappan3440',
#   'Comment_Published': '2023-10-02T10:06:31Z'},
#  {'Comment_Id': 'Ugz0RgNsgipEUnvYRD94AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Anna you hire a good editor bcuz your video is highly edu potential but you lose in Editing, if you correct it definitely unstoppable',
#   'Comment_Author': '@rifaqueibrahim9508',
#   'Comment_Published': '2023-10-13T12:43:53Z'},
#  {'Comment_Id': 'Ugx_hmW4FYrL6hgnmkR4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'A❤❤❤❤A❤❤❤❤❤A',
#   'Comment_Author': '@goldberggoldberg6418',
#   'Comment_Published': '2023-10-03T05:41:43Z'},
#  {'Comment_Id': 'UgymcwISRdlwvVVWvdh4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'My visionary idea of Quantum Logic Gates to empower human thought processes\r<br>Sir, Quantum computers would be the most powerful computers in the near future and these computers would be millions or even billions of times faster than the fastest supercomputers today. An electron would be in superposition when we don’t observe it and is capable of becoming a processor to process of billions of calculations in Femto-seconds that would certainly take today’s supercomputers billions of years to solve. Quantum entanglement is a physical phenomenon in which two particles behave very similarly though they are separated by billions of light years. These two particles are in their superpositions and by observing the end result of one particle, one could predict the end result of the other particle’s behavior. An electron as per Erwin Schrodinger’s equation could behave like a wave. Quantum computers could be built based on the strange behavioural properties of leptons and other subatomic particles. Just like the logic gates AND, OR and NOT used in digital computers, I have created fundamental Quantum Logic Gates for quantum computers to process billions of data and to produce the output in Femto-seconds. I don’t believe in intelligent software tools like ChatGPT. These are not intelligent tools that could make a real decision endowed with consciousness. The winner of 2020 Nobel Prize in Physics, Roger Penrose has given his sensible arguments that consciousness and computations are two different things. It is highly impossible at the present time with the current physical knowledge to explain the physical properties of consciousness. We can’t make our present rudimentary quantum computers to be endowed with consciousness and artificially intelligence but if there is any possibility in the future then it might end up in the materialization of powerful machines that could either enslave or destroy the human species because survival is the basic quality of anything that is aware of its surrounding. Mathematicians and Physicists are really freed from the burden of focusing on technical derivations because of today’s powerful digital computers but rather they are engaged with conceptual ideas which compose the very heart of math and physics. \r<br>I have developed some fundamental quantum logic gates while mentoring my students for a competition a week ago and these fundamental quantum logic gates could speed up our thought processes and make them more precise and conclusive. These quantum logic gates could be used in quantum computers to make them more intelligent and to make decisions and solve real life problems in Femto-seconds. The two quantum logic circuits which I have designed are the convergent quauntum logic gate and the divergent quantum logic gate. These two quantum logic gates could be used to speed up our thought processes to a fraction of a second. \r<br>Convergent Quantum Logic Gate:\r<br>      Imagine a scenario that a very creative AI expert has received hundreds of offer letters from Open AI, Google, Microsoft...etc. This scenario really confused him because he has no real work experience and exposure and it would take him at least a month or two to make a proper decision to find a comfortable job which might be more than the expected time given by the companies. The convergent quantum logic gates could take these inputs and process them in Femto-seconds to produce the needful result for the situation with incredible accuracy. \r<br>Divergent Quantum Logic Gate: Imagine a scenario where Sergei Brin and Larry Page who are the owners of Google calls on their foremost employee, Sundar Pitchai to come out with lots of intelligent and specific software tools to beat Open AI. It would take Sundar Pitchai to come out smartly with divergent solutions in 6 months time whereas a divergent quantum logic gate could process this in a fraction of a second to come out with workable divergent solutions. \r<br>These qu ...
#   'Comment_Author': '@hectorrajclaudius2562',
#   'Comment_Published': '2023-10-01T06:53:24Z'},
#  {'Comment_Id': 'Ugyxrf0jG4fazm3IUIp4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Thanks sir ❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2023-10-01T02:42:01Z'},
#  {'Comment_Id': 'UgzlbEfPAatDRSsXJc54AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': '❤❤❤',
#   'Comment_Author': '@kannan3920',
#   'Comment_Published': '2023-09-28T18:11:06Z'},
#  {'Comment_Id': 'UgyJAKV0bB0LC-wI_014AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Super sir.',
#   'Comment_Author': '@Manikandan-kx8uv',
#   'Comment_Published': '2023-09-28T18:10:40Z'},
#  {'Comment_Id': 'UgyzROy8jtT2dJXnCIJ4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Sir recently I talk about energies concept to you I wish to show my formula about energy E=hc²f/v² which is equal to Einstein&#39;s energy =mc² Einstein said in his formula E= mc²  this energy is act only for photons and also for  radium active substance like uranium while fission but I said that a normal person also had mc² energy when he start to run at his energy is directly proportional to frequency while his squared velocity inversely proportional to energy which equals I need a constant hc² therefore a new energy formula was formed which is equal to mc²<br>Hence I said that a normal person also had a mass which convert to his energy when he runs I not had  a  practical experiment it fully theorical experiment with mathematics l am a mathemical believer like Neils Bohr In my equation the mathematics tells that an all objects has mc² energy including photons also .it just my thought I supposed. if all object has mc² energy  then the general mc² energy is expressed in the form of E = hc²f/v² was supposed by this  mathematics according to me, l thought it  is correct but I don&#39;t know how others look this formula sir you say is correct or wrong ? I waiting for your reply ......',
#   'Comment_Author': '@dhanasegarandhanush2494',
#   'Comment_Published': '2023-09-28T15:56:12Z'},
#  {'Comment_Id': 'Ugzk7ovldwFQ_p-6wgZ4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Bro tell about Richard Feynman interesting facts',
#   'Comment_Author': '@instantupdates9352',
#   'Comment_Published': '2023-09-28T14:56:33Z'},
#  {'Comment_Id': 'UgyMyBEP4mnXkhODIvZ4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'சூப்பர் தம்பி ❤❤❤',
#   'Comment_Author': '@scienceknowledge1000',
#   'Comment_Published': '2023-09-28T14:52:27Z'},
#  {'Comment_Id': 'UgxZ_ykdB5zvFk_61K94AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Sir you can make a video on rocket <br>Science',
#   'Comment_Author': '@arvindsworld7234',
#   'Comment_Published': '2023-09-28T14:42:04Z'},
#  {'Comment_Id': 'Ugxw7T9fWFn4_Obm8PN4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Great Bro!! I feel large telescopes shall be installed on moon. <br>Bro, I see Carl Sagan has told about life in other part of universe. Kindly summarize his public lectures. 🙏 <br>What is opinion about Fermi paradox 😊😊',
#   'Comment_Author': '@kannadassasn',
#   'Comment_Published': '2023-09-28T14:39:03Z'},
#  {'Comment_Id': 'Ugzr64UJXvqxxQwsTEx4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Nice information',
#   'Comment_Author': '@Mathematics0227',
#   'Comment_Published': '2023-09-28T14:27:50Z'},
#  {'Comment_Id': 'UgxRP1XyVrwRl373VRB4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'தகவலுக்கு மிக்க நன்றி🙏',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2023-09-28T13:46:08Z'},
#  {'Comment_Id': 'UgyP3gk6TaUNPTb_weN4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'If anyone forgets like, please do that.',
#   'Comment_Author': '@selvakumar-cq2zb',
#   'Comment_Published': '2023-09-28T13:34:35Z'},
#  {'Comment_Id': 'UgxpjyCOiV9H3gMtFD54AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Hi sir plz make some different topics not only quantum lecture plz..... My request or another scientist  biography',
#   'Comment_Author': '@pichikalokesh2078',
#   'Comment_Published': '2023-09-28T13:22:47Z'},
#  {'Comment_Id': 'UgzCqv1us5Lg0P2FviV4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'Minkowiski space time diagram explain pannuga bro',
#   'Comment_Author': '@PriyadharshanDharshan-di2wr',
#   'Comment_Published': '2023-09-28T13:12:50Z'},
#  {'Comment_Id': 'Ugwpht9rjPH8EBkDH5V4AaABAg',
#   'Video_Id': 'Sso4-56DB_g',
#   'Comment_Text': 'the moment when u start to love and observe astronomy...then we became so optimistic.. without ego, jealous and other than...😊life maybe long for you but it&#39;s actually short from outside...indeed we are speck of dust ❤',
#   'Comment_Author': '@varsha_1703',
#   'Comment_Published': '2023-09-28T13:10:38Z'},
#  {'Comment_Id': 'Ugzjp4CR4F5mT_wW1np4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Happy new year sir',
#   'Comment_Author': '@navaneethakrishannavaneeth3850',
#   'Comment_Published': '2024-01-02T01:09:15Z'},
#  {'Comment_Id': 'UgwOlNLYAxPX5E8pxIV4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'super naaaaaa',
#   'Comment_Author': '@alavudeen218',
#   'Comment_Published': '2023-10-05T17:52:08Z'},
#  {'Comment_Id': 'UgzHzIIMO3xCrfq2ImN4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': '❤🎉❤🎉❤',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-10-02T08:20:27Z'},
#  {'Comment_Id': 'Ugz98Ltf2d1wGpeKuA54AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Super vera level explanation la i am  inspector of police paramakudi town sir thank you very y',
#   'Comment_Author': '@navaneethakrishannavaneeth3850',
#   'Comment_Published': '2023-10-01T17:42:01Z'},
#  {'Comment_Id': 'UgwNGml-wTASpTU_ayh4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Thank you ❤❤❤❤❤',
#   'Comment_Author': '@thirdeyepk8706',
#   'Comment_Published': '2023-10-01T14:30:24Z'},
#  {'Comment_Id': 'Ugy-vIIQAfRdISngwlN4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Your explanation is beautiful.',
#   'Comment_Author': '@LOKESHKUMAR-mx9qc',
#   'Comment_Published': '2023-09-30T04:03:17Z'},
#  {'Comment_Id': 'UgwHIXsKMRqhzUPVABt4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'எளிய தமிழ் எளிமையான விளக்கம் எப்படி அய்யா முடியுது உன்னால்  .. அற்புதம் ஐயா ..நீ மனித குலத்துக்கு செய்யும் பேருபுகாரம் உனது இவ்விஞ்ஞான தொடர்தான்  ஐயா ..குறைந்தது கிழமைக்கு இரண்டாவது தா ஐயா...உனக்கு புண்ணியமாகப்போகும்....ஆடைக்கொருமுறை கோடைக்கொருமுறை வந்து போகாதே ...',
#   'Comment_Author': '@abdulyouare100percentright9',
#   'Comment_Published': '2023-09-29T17:15:29Z'},
#  {'Comment_Id': 'Ugyxa8lWaoVAZuvYST54AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'NANRI BRO',
#   'Comment_Author': '@nagarasan',
#   'Comment_Published': '2023-09-29T06:50:22Z'},
#  {'Comment_Id': 'Ugx9FAwDcfFJrMJs9yB4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Super',
#   'Comment_Author': '@DINESHPRABHUMASS.',
#   'Comment_Published': '2023-09-28T14:16:19Z'},
#  {'Comment_Id': 'UgxgFjR8FxHyFJchWEJ4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Nanri brother nalla pathivu',
#   'Comment_Author': '@senthilraj4951',
#   'Comment_Published': '2023-09-28T07:48:16Z'},
#  {'Comment_Id': 'UgxNIhfxNKphWrjdRSZ4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Bro pls atleast post a video weekly twise we are eagerly waiting for your video❤😢',
#   'Comment_Author': '@sathishrajan7023',
#   'Comment_Published': '2023-09-27T13:46:13Z'},
#  {'Comment_Id': 'UgyEbk19JgNu7bpzSb14AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Hi bro. How are you today. Ennoda question ⁉️ enna na<br> Inka niraiya. Sorry I forgot my question. ...  Next time I asked you my question.',
#   'Comment_Author': '@prakashsenthil5553',
#   'Comment_Published': '2023-09-26T14:04:06Z'},
#  {'Comment_Id': 'UgyI4mREafCLGIndlot4AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'விண்கல்லில் இருந்து கரிமச்சேர்மத்தின் மூலக்கூறுகள் கிடைக்கிறதானால் உயிர் உருவாக சாத்தியமாக இருக்கலாம். ஆனால் உயிர்ச்செல் தோற்றம் பூமிதான்.முதல் செல் விலங்குசெல்லா? தாவரசெல்லா?புதிய தனிமம் கண்டுபிடிக்கப்படலாம். Sirஇதன் ஆய்வு முடிவுகளை பற்றி வீடியோ போடுங்க.',
#   'Comment_Author': '@kaliraj9901',
#   'Comment_Published': '2023-09-26T13:55:56Z'},
#  {'Comment_Id': 'UgzFOfpiTjyU7y42S194AaABAg',
#   'Video_Id': 'D3jiAxVmYr4',
#   'Comment_Text': 'Nandri Sam',
#   'Comment_Author': '@thamizhi1524',
#   'Comment_Published': '2023-09-26T10:41:13Z'},
#  ...]

# %%
#get playlist details

def get_playlist_details(channel_id):
    next_page_token=None
    All_data=[]
    while True:
        request=youtube.playlists().list(
            part='snippet,contentDetails',
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response=request.execute()

        for item in response['items']:
            data=dict(Playlist_Id=item['id'],
                    Title=item['snippet']['title'],
                    Channel_Id=item['snippet']['channelId'],
                    Channel_Name=item['snippet']['channelTitle'],
                    PublishedAt=item['snippet']['publishedAt'],
                    Video_Count=item['contentDetails']['itemCount'])
            All_data.append(data)
        
        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return All_data

# %%
playlist_details=get_playlist_details("UChGd9JY4yMegY6PxqpBjpRA")

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PLgctjL4oxHAsIkA1Np-1Z3U5ufFeVPBxG',
#   'Title': 'Quantum Mechanics Lectures in Tamil',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2023-03-29T12:23:10Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PLgctjL4oxHAuP0ALXEJDuawYaTGyguu2F',
#   'Title': 'Richard Feynman',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-12-24T15:03:27Z',
#   'Video_Count': 9},
#  {'Playlist_Id': 'PLgctjL4oxHAv13mHacoQCGidm6mWlK7Pm',
#   'Title': 'Black Hole',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-08-25T07:13:57Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PLgctjL4oxHAtKInGo2EjXOBq4sqfTfll7',
#   'Title': 'Black Hole',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-08-25T07:13:54Z',
#   'Video_Count': 0},
#  {'Playlist_Id': 'PLgctjL4oxHAuTH4vM5Y3Fp-1yNC4Rq4j7',
#   'Title': 'Galileo Galilei',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-06-23T08:05:33Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PLgctjL4oxHAs0VfJNQQW1EwL7KZ9LIowl',
#   'Title': 'Spacetime',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-06-20T07:18:30Z',
#   'Video_Count': 3},
#  {'Playlist_Id': 'PLgctjL4oxHAvnDjqxswXeE0P_CIPb6uYH',
#   'Title': 'Plus Two Physics',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-04-21T18:09:05Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PLgctjL4oxHAu-RXkV4tveHlaOxLjCNJHK',
#   'Title': 'Scientist Interview',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-03-18T09:13:57Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PLgctjL4oxHAt4WfbhvFDlrr1SdyHRfscT',
#   'Title': 'Bose Einstein',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-02-20T11:33:04Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLgctjL4oxHAvRKVXTk2IxLLukcIx37M9i',
#   'Title': 'PhD Information',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-02-06T10:07:52Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLgctjL4oxHAtDbFuxurdSy8i1KqA7gj-j',
#   'Title': 'Travel vlogs - Sharing my travel experience thanking the subscribers',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-01-23T18:06:18Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PLgctjL4oxHAtGXWmhboYnCoP8X54pjsUS',
#   'Title': 'Scientist Story',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-12-28T14:44:48Z',
#   'Video_Count': 36},
#  {'Playlist_Id': 'PLgctjL4oxHAvdYFwFKSouv3dSUP1MwZza',
#   'Title': 'James Webb Space Telescope',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-12-21T21:08:16Z',
#   'Video_Count': 13},
#  {'Playlist_Id': 'PLgctjL4oxHAsgcE80AV8WCxthkTuUWXN_',
#   'Title': 'Quantum',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-26T14:04:38Z',
#   'Video_Count': 16},
#  {'Playlist_Id': 'PLgctjL4oxHAvjDhQagRWibAdwp6dg5XG0',
#   'Title': 'Stephen Hawking',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T14:31:22Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PLgctjL4oxHAtYcFQ8rHuTnHyuCMtTijtt',
#   'Title': 'Important Science Topics',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T14:29:34Z',
#   'Video_Count': 96},
#  {'Playlist_Id': 'PLgctjL4oxHAuRq-InrjEEZVTIlCa6vMJ-',
#   'Title': 'Science Stories in Tamil',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T14:20:54Z',
#   'Video_Count': 76},
#  {'Playlist_Id': 'PLgctjL4oxHAsb2h9SPYwem9az_GLByma2',
#   'Title': 'Motivational Videos - Also Self Intro',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T14:19:14Z',
#   'Video_Count': 22},
#  {'Playlist_Id': 'PLgctjL4oxHAtmeIUKd4hF16hSd6T2sB1P',
#   'Title': 'New Scientific News',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T14:17:40Z',
#   'Video_Count': 80},
#  {'Playlist_Id': 'PLgctjL4oxHAtztRaw1tAdq36yi5kR-Ccp',
#   'Title': 'Nobel Prize',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T14:15:42Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PLgctjL4oxHAuKwKjtB5mm7IFb_mfHS1w0',
#   'Title': 'Einstein',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T14:13:31Z',
#   'Video_Count': 15},
#  {'Playlist_Id': 'PLgctjL4oxHAspkFL8qJdpeV5GJaH0-KIA',
#   'Title': 'Science Battle Between Scientists',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T09:42:58Z',
#   'Video_Count': 5}]

# %%
#upload to mongodb

from pymongo import MongoClient
client=pymongo.MongoClient("mongodb+srv://mailtonandhinijawahar:thiruppathi@cluster0.ht5ek.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["Youtube_data"]
coll1=db["channel_details"]

# %%
all_channels = []
db=client["Youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
    all_channels.append(ch_data["channel_information"]["Channel_Name"])

# %%
def Channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    
    return "upload completed successfully"

# %%
insert=Channel_details("UCAsC3EL8tYlunqN__15WzdQ")

# %%
insert
# Out:
# 'upload completed successfully'

# %%
def channels_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="8997",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                            Channel_ID varchar(80) primary key,
                                                            Subscribers bigint,
                                                            Views bigint,
                                                            Total_vedios int,
                                                            Channel_Description text,
                                                            Playlist_Id varchar(80))'''
        cursor.execute(create_query)
        mydb.commit()
    except:
        print("channel table already created")

    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=pd.DataFrame(ch_list)


    for index,row in df.iterrows():
        insert_query='''insert into channels(Channel_Name,
                                            Channel_ID,
                                            Subscribers,
                                            Views,
                                            Total_vedios,
                                            Channel_Description,
                                            Playlist_Id)

                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
                row['Channel_ID'],
                row['Subscribers'],
                row['Views'],
                row['Total_vedios'],
                row['Channel_Description'],
                row['Playlist_Id'])

        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("channel values are alredy inserted")

# %%
def playlist_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="8997",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query='''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                        Title varchar(80) ,
                                                        Channel_Id varchar(100),
                                                        Channel_Name varchar(100),
                                                        PublishedAt timestamp,
                                                        Video_Count int)'''

    cursor.execute(create_query)
    mydb.commit()

    pl_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append((pl_data["playlist_information"][i]))
    df1=pd.DataFrame(pl_list)



     
    for index,row in df1.iterrows():
        insert_query='''insert into playlists(Playlist_Id,
                                        Title,
                                        Channel_Id,
                                        Channel_Name,
                                        PublishedAt,
                                        Video_Count)

                                        values(%s,%s,%s,%s,%s,%s)'''

        values=(row['Playlist_Id'],
            row['Title'],
            row['Channel_Id'],
            row['Channel_Name'],
            row['PublishedAt'],
            row['Video_Count'])


        cursor.execute(insert_query,values)
        mydb.commit()

# %%
def videos_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="8997",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query='''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                    Channel_Id varchar(100) ,
                                                    Video_Id varchar(30) primary key,
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Descriptions text,
                                                    Published_Date timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_Count int,
                                                    Definition varchar(10),
                                                    Caption_Status varchar(50)
                                                    )'''
                
                                



    cursor.execute(create_query)
    mydb.commit()

    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append((vi_data["video_information"][i]))
    df2=pd.DataFrame(vi_list)

    for index,row in df2.iterrows():
        insert_query='''insert into videos(Channel_Name,           
                                        Channel_Id,
                                        Video_Id,
                                        Title,
                                        Tags,
                                        Thumbnail,
                                        Descriptions,
                                        Published_Date,
                                        Duration,
                                        Views,
                                        Likes,
                                        Comments,
                                        Favorite_Count,
                                        Definition,
                                        Caption_Status
                                        )

                                        values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
    


        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Video_Id'],
                row['Title'],
                row['Tags'],
                row['Thumbnail'],
                row['Descriptions'],
                row['Published_Date'],
                row['Duration'],
                row['Views'],
                row['Likes'],
                row['Comments'],
                row['Favorite_Count'],
                row['Definition'],
                row['Caption_Status']
                
                )
        


        cursor.execute(insert_query,values)
        mydb.commit()

# %%
def comments_table():
        mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="8997",
                        database="youtube_data",
                        port="5432")
        cursor=mydb.cursor()

        drop_query='''drop table if exists comments'''
        cursor.execute(drop_query)
        mydb.commit()

        create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(50),
                                                        Comment_Text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp
                                                        )'''
        cursor.execute(create_query)
        mydb.commit()

        com_list=[]
        db=client["Youtube_data"]
        coll1=db["channel_details"]
        for com_data in coll1.find({},{"_id":0,"comment_information":1}):
                for i in range(len(com_data["comment_information"])):
                        com_list.append((com_data["comment_information"][i]))
        df3=pd.DataFrame(com_list)

        for index,row in df3.iterrows():
                insert_query='''insert into comments(Comment_Id,           
                                                Video_Id,
                                                Comment_Text,
                                                Comment_Author,
                                                Comment_Published
                                                )

                                                values(%s,%s,%s,%s,%s)'''
        


                values=(row['Comment_Id'],
                        row['Video_Id'],
                        row['Comment_Text'],
                        row['Comment_Author'],
                        row['Comment_Published']
                        
                        )
                


                cursor.execute(insert_query,values)
                mydb.commit()

# %%
def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_table()

    return "Tables Created Successfully"

# %%
Tables = tables()

# %%
def show_channels_table():
    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=st.dataframe(ch_list)

    return df

# %%
def show_playlists_table():
    pl_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append((pl_data["playlist_information"][i]))
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append((vi_data["video_information"][i]))
    df2=st.dataframe(vi_list)

    return df2

# %%
def show_comments_table():
    com_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
                for i in range(len(com_data["comment_information"])):
                        com_list.append((com_data["comment_information"][i]))
    df3=st.dataframe(com_list)

    return df3

# %%
# streamlit part

with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("Skill Take Away")
    st.caption("Python Scripting")
    st.caption("Data Collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management using MongoDB and SQL")

channel_id=st.text_input("Enter the Channel ID")

if st.button("Collected and store data"):
    ch_ids=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_data.append(ch_data["channel_information"]["Channel_ID"])

    if channel_id in ch_ids:
        st.success("Channel Details of the given channel id already exists")
    
    else:
        insert=channel_details(channel_id)
        st.success(insert)
        
unique_channel=st.selectbox("Select the channel",["channel1","channel2"])


if st.button("Migrate to sql"):
    Table=tables()
    st.success(Table)

show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table=="CHANNELS":
    show_channels_table()

elif show_table=="PLAYLISTS":
    show_playlists_table()

elif show_table=="VIDEOS":
    show_videos_table()

elif show_table=="COMMENTS":
    show_comments_table()
# Out:
# 2024-11-17 10:10:32.059
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\DELL\Desktop\New folder\GUVI DS YOUTUBE HARVEST\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-17 10:10:32.064 Session state does not function when running a script without `streamlit run`

# %%
# SQL CONNECTION:

mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="8997",
                        database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

question=st.selectbox("Select your Question",("1. All the videos and the channel name",
                                              "2. Channels with most number of videos",
                                              "3. 10 most viewed videos",
                                              "4. Comments in each videos",
                                              "5. Videos with highest likes",
                                              "6. Likes of all videos",
                                              "7. Views of each channel",
                                              "8. Videos published in the year of 2022",
                                              "9. Average duration of all videos in each channel",
                                              "10. Videos with highest number of comments"))


if question=="1. All the videos and the channel name":
    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)
    
elif question=="2. Channels with most number of videos":
    query2='''select channel_name as channelname,total_videos as no_videos from channels
              order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2=pd.DataFrame(t2,columns=["channel name","No of videos"])
    st.write(df2)
    
elif question=="3. 10 most viewed videos":
    query3='''select views as views,channel_name as channelname,title as videotitle from videos 
              where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["views","channel name","videotitle"])
    st.write(df3)
    
elif question=="4. Comments in each videos":
    query4='''select comments as no_comments,title as videotitle from videos where comments is not null '''
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.write(df4)
    
elif question=="5. Videos with highest likes":
    query5='''select title as videotitle,channel_name as channelname, likes as likecount
              from videos where likes is nott null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.write(df5)
    
elif question=="6. Likes of all videos":
    query6='''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["likecount","videotitle"])
    st.write(df6)
    
elif question=="7. Views of each channel":
    query7='''select channel_name as channelname,views as totalviews from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channel name","totalviews"])
    st.write(df7)
    
elif question=="8. Videos published in the year of 2022":
    query8='''select title as video_title,published_date as videorelease,channel_name as channelname from video
              where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["videotitle","published_date","channelname"])
    st.write(df8)
    
elif question=="9. Average duration of all videos in each channel":
    query9='''select channel_name as channelname,AVG(duration) as averageduration from videos group by channel_name '''
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["channelname","averageduration"])
    st.write(df9)
    T9=[]
    for index,row in df9.iterrows():
        channel_title=row["channelname"]
        average_duration=row["averageduration"]
        average_duration_str=str(average_duration)
        T9.append(dict(channeltitle=channel_title,avgduration=average_duration_str))
    df1=pd.DataFrame(T9)
    st.write(df1)

elif question=="10. Videos with highest number of comments":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is
               not null order by desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="8997",
                        database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

if question=="10. Videos with highest number of comments":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is
               not null order by desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)
